# %% [markdown]
# Desarrollar una aplicación en Python utilizando el paradigma de programación orientada a objetos y las librerías de pandas, numpy, matplotlib, datetime y folium.
#
# La aplicación a desarrollar permitirá procesar y analizar los datos de ventas de una empresa. Para ello, se debe definir una clase llamada "DatosVentas", que reciba como parámetro la ruta de un archivo CSV con los datos de ventas y que tenga un método llamado "procesar_datos" para agregar columnas al DataFrame de pandas con el mes y el año de la venta.
# Posteriormente, se debe definir una clase llamada "AnalizadorVentas" que reciba como parámetro una instancia de la clase "DatosVentas" y que tenga tres métodos: "obtener_ventas_totales", "obtener_ventas_promedio_por_mes" y "obtener_productos_mas_vendidos". Estos métodos deberán devolver la suma total de las ventas, las ventas promedio por mes y los productos más vendidos, respectivamente.
# Por último, se debe definir una clase llamada "VisualizadorVentas" que reciba como parámetro una instancia de la clase "DatosVentas" y que tenga cuatro métodos: "graficar_ventas_totales", "graficar_ventas_promedio_por_mes", "graficar_productos_mas_vendidos" y "graficar_mapa_ventas". Estos métodos deberán graficar la información obtenida en los métodos de la clase "AnalizadorVentas" y mostrar un mapa de calor con las ventas por país.
#
# VER LAS COLUMNAS DE LOS FICHERO
# #print(escritor_csv.fieldnames)

# %%
import csv
import random
import datetime

# Generar datos de ventas ficticios con listas
productos = ['Producto 1', 'Producto 2', 'Producto 3']
paises = ['País 1', 'País 2', 'País 3']
ventas = []
for i in range(1000):
    #se genera un diccionario con los datos y los valores de mes y dias
    venta = {}
    venta['Fecha'] = datetime.date(2022, random.randint(1, 12), 
                                   random.randint(1, 28))
    venta['Producto'] = random.choice(productos)
    venta['País'] = random.choice(paises)
    venta['Ventas'] = random.randint(100, 10000)
    ventas.append(venta)

# Escribir los datos en un archivo CSV
with open('datos_ventas.csv', mode='w', newline='') as archivo_csv:
    #crea los atributos de las columnas
    nombres_columnas = ['Fecha', 'Producto', 'País', 'Ventas']
    #crea el objeto archivo_csv y agrega sus columnas
    escritor_csv = csv.DictWriter(archivo_csv, fieldnames=nombres_columnas)
    #escribe los atributos de la tabla en el fichero
    escritor_csv.writeheader()
    
    for venta in ventas:
        #writeheader: escribimos los valores en 
        # las filas de la tabla
        escritor_csv.writerow(venta)

# %% [markdown]
# Clase DatosVentas:
# inicializar: Método constructor que inicializa la instancia de la clase, toma como argumento la ruta del archivo CSV de ventas y carga los datos en un objeto DataFrame de pandas.
# procesar_datos: Este método procesa los datos de ventas y agrega dos nuevas columnas al objeto DataFrame: una columna para el mes de la venta y otra para el año de la venta.
# obtener_datos: Retorna el objeto DataFrame con los datos de ventas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import folium

class DatosVentas:
    def __init__(self, ruta_archivo):
        #sep= separador de campos o columnas
        self.datos = pd.read_csv(ruta_archivo, sep=",", encoding='')

    def procesar_datos(self):
        # convertimos la columna en objeto de fecha para hacer calculos
        self.datos['Fecha'] = pd.to_datetime(self.datos['Fecha'])
        #usamos de fecha el mes
        self.datos['Mes'] = self.datos['Fecha'].dt.month
        #usamos de fecha el año
        self.datos['Año'] = self.datos['Fecha'].dt.year
        
    def obtener_datos(self):
        return self.datos

# %% [markdown]
# IMPORTANTE: DEBES CARGAR "PROCESAR_DATOS" PARA QUE LAS OTRAS CLASES
# Y METODOS FUNCIONEN BIEN

# %%
ventas_lunes= DatosVentas('datos_ventas.csv')
ventas_martes= DatosVentas('datos_ventas.csv')

#acceder a todos los atributos del dataframe
#print(ventas_martes.datos)

#obtener los datos sin el mes y año del dataframe
#ventas_lunes.obtener_datos()

#agregamos los nuevos campos de mes y año 
# con el metodo procesar_datos y mostramos el nuevo dataframe
ventas_lunes.procesar_datos()
#ventas_lunes.datos

# %% [markdown]
# Clase AnalizadorVentas:
# inicializar: Método constructor que inicializa la instancia de la clase, toma como argumento un objeto de la clase DatosVentas.
# obtener_ventas_totales: Retorna la suma total de las ventas.
# obtener_ventas_promedio_por_mes: Retorna un objeto DataFrame que contiene el promedio de ventas por mes y año.
# obtener_productos_mas_vendidos: Retorna un objeto DataFrame que contiene los n (el usuario debe indicar el valor de n) productos más vendidos.

# %%
class AnalizadorVentas:
    def __init__(self, datos_ventas):
        #accede al dataframe con sus atributos con (.datos)
        self.datos = datos_ventas.datos
        
    def obtener_ventas_totales(self):
        #accede al campo ventas y suma
        return self.datos['Ventas'].sum()
        
    def obtener_ventas_promedio_por_mes(self):
        #del dataframe self.datos agrupa los nuevos campos (año, mes)
        # y pone la media (por grupos) ->Idx Año  Mes   Ventas
        #                                0  2021  Ene  1000.00
        return self.datos.groupby(['Año', 'Mes'])['Ventas'].mean(
        ).reset_index() #reset index: crea una secuencia numerica 
                        #con indices para usarla con funciones
        
    def obtener_productos_mas_vendidos(self, n):
        #agrupa por productos, suma los grupos de los productos y 
        # selecciona los productos que tienen mas ventas 
        return self.datos.groupby('Producto')['Ventas'].sum(
        ).nlargest(n).reset_index()

# %%
#toma como argumento un objeto de la clase DatosVentas
analizador_v= AnalizadorVentas(ventas_lunes)

#Retorna la suma total de las ventas
#analizador_v.obtener_ventas_totales()

#Retorna un objeto DataFrame que contiene el promedio de 
# ventas por mes y año.
#analizador_v.obtener_ventas_promedio_por_mes()

#Retorna un objeto DataFrame que contiene los n (los numero 
#de fila por indice con el productos más vendidos, que se 
# muestra de forma descendente, es decir, del producto mas vendido
# al menos vendido.
analizador_v.obtener_productos_mas_vendidos(2)
# Out:
#      Producto   Ventas
# 0  Producto 2  1766810
# 1  Producto 1  1636550

# %% [markdown]
# Clase VisualizadorVentas:
# init: Método constructor que inicializa la instancia de la clase, toma como argumento un objeto de la clase DatosVentas.
# graficar_ventas_totales: crea la evolución temporal de las ventas.
# graficar_ventas_promedio_por_mes:  gráfica que muestra el promedio de ventas por mes y año.
# graficar_productos_mas_vendidos: gráfica que muestra los n productos más vendidos.
# graficar_mapa_ventas: gráfica que muestra un mapa de calor de las ventas por país.

# %% [markdown]
# RECUERDA QUE PUEDES ACCEDER A LAS VARIABLES LOCALES DE UNA CLASE CREANDO UNA FUNCION QUE TE DEVUELVA EL VALOR DE LA VARIABLE

# %%
class VisualizadorVentas:
    def __init__(self, datos_ventas):
        #datos_ventas.datos hace referencia a los datos del dataframe de 
        #la clase  padre
        self.datos_ventas = datos_ventas.datos

    def graficar_ventas_totales1(self):
        #agrupa la suma de ventas por fecha y el resultado lo almacena
        #en el "grafico de linea" del metodo plot de la libreria pandas
        self.datos_ventas.groupby(["Fecha"])["Ventas"].sum().reset_index(
        ).plot(x="Fecha", y="Ventas", 
                    kind="line", xlabel="Fecha", ylabel="Ventas"
                    , title="Ventas totales por fecha")
        
    def graficar_ventas_totales2(self):
        #del objeto dataframe datos_ventas agrupamos por fecha y sumamos
        #las ventas para crear otro dataframe con esos nuevos datos que 
        #se guarda en datos_por_fecha para usarlo en el otro "grafico de linea"
        datos_por_fecha = self.datos_ventas.groupby(["Fecha"])["Ventas"].sum(
        ).reset_index()

        #del nuevo dataframe datos_por_fecha usamos los campos Fecha(X), 
        # Ventas(Y) para ponerlos en los parametros del metodo
        plt.plot(datos_por_fecha.Fecha, datos_por_fecha.Ventas, color='GREY', 
                 marker='*',linestyle='--') #marker y linestyle son los puntos y lineas del grafico
        
        #Damos formato al grafico
        plt.title('Ventas totales por fecha')
        plt.xlabel('Fecha')
        plt.ylabel('Ventas')
        plt.show()

    def graficar_ventas_totales3(self):
        #hace lo mismo que el metodo anterior
        datos_por_fecha = self.datos_ventas.groupby(["Fecha"])["Ventas"].sum(
        ).reset_index()

        plt.plot(datos_por_fecha.Fecha, datos_por_fecha.Ventas, color='green', 
                 marker='o')
        plt.title('"Ventas totales por fecha"')
        plt.xlabel('Fecha')
        plt.ylabel('Ventas')
        plt.show()
        
    def graficar_ventas_promedio_por_mes(self):
        #agrupa los campos año y mes y los une con la media de ventas 
        ventas_por_mes = self.datos_ventas.groupby(['Año', 
        'Mes'])['Ventas'].mean().reset_index()

        #ponemos en x mes y y en ventas
        plt.plot(ventas_por_mes['Mes'], ventas_por_mes['Ventas'])
        
        plt.title('Ventas promedio por mes')
        
        plt.xlabel('Mes')
        
        plt.ylabel('Ventas')
        
        plt.show()
        
    def graficar_productos_mas_vendidos(self, n):
        #agrupamos, sumamos las ventas y guardamos los datos de producto 
        # ventas de mayor a menor (nlargest -segun la fila que ponga usuario-)
        productos_mas_vendidos = self.datos_ventas.groupby('Producto')[
            'Ventas'].sum().nlargest(n).reset_index()
        
        #bar: gráfico de barras eje x y y
        plt.bar(productos_mas_vendidos['Producto'], productos_mas_vendidos[
            'Ventas'])
        
        #muestra el parametro de n
        plt.title('Los {} productos más vendidos'.format(n))
        plt.xlabel('Producto')
        plt.ylabel('Ventas')
        plt.show()
        
    def graficar_mapa_ventas(self):
        #Agrupa los datos de ventas por país y suma las ventas para cada país.
        datos_por_pais = self.datos_ventas.groupby('País')['Ventas'
        ].sum().reset_index()

        #	    País	Ventas     <--datos_por_pais
        #    0	País 1	1617287
        #    1	País 2	1627373
        #    2	País 3	1640510
        
        #crea la matriz de esta manera, accede al dataframe y accede a 
        #la columna ventas
        data = np.array([datos_por_pais.Ventas]) 

        #La función plt.subplots() crea una figura y uno o varios ejes. 
        #fig y ax: se utiliza para establecer propiedades generales de la 
        # figura (tamaño, título, leyenda, no o varios ejes dentro de la figura)
        fig, ax = plt.subplots() #esta funcion devuelve dos objetos
        
        #que crea el mapa de calor utilizando los valores de la matriz 
        # data y el mapa de colores "summer".
        im = ax.imshow(data, cmap='summer')

        #data.shape[0] retorna el número de filas 
        # y data.shape[1] retorna el número de columnas de data
        for i in range(data.shape[0]):
            for j in range(data.shape[1]):
                #escribe en el grafico la informacion de data
                #j,i: posicions/ data[i,j]: el contenido de data
                text = ax.text(j, i, data[i, j],
                            ha="center", va="center", color="black")
        
        # Añadir la barra de color
        #im: objeto de la imagen 
        #ax: ejes se dibujará la barra de colores
        cbar = ax.figure.colorbar(im, ax=ax)

        # Ajustar la etiqueta de los países en el eje x
        #se establece en un rango que va desde 0 hasta la 
        # longitud de la segunda dimensión de la matriz data.
        ax.set_xticks(np.arange(data.shape[1]))
        #escribe la informacion de la columna pais
        ax.set_xticklabels(['País 1', 'País 2', 'País 3'])

        #quita la informacion de y
        ax.set_yticks([])


        # Rotar las etiquetas del eje x
        plt.setp(ax.get_xticklabels(), rotation=90, ha="right",
                rotation_mode="anchor")

        # Ajustar los márgenes del gráfico
        plt.tight_layout()

        plt.show()

# %%
#PRUEBAS DE METODOS Y OBJETOS 
#v= VisualizadorVentas(ventas_lunes)
#
##v.graficar_ventas_totales()
##
##v.graficar_ventas_totales2()
##
##v.graficar_ventas_totales3()
#
##v.graficar_ventas_promedio_por_mes()
#
#v.graficar_productos_mas_vendidos(2)
#
VentasLunes = DatosVentas('datos_ventas.csv')

VentasLunes.procesar_datos()

VentasLunes.obtener_datos()
#
#VentasMartes = DatosVentas('datos_ventas.csv')
#
#VentasLunes.datos
#
#VentasLunes.obtener_datos()
#
#VentasLunes.procesar_datos()
##ventas_lunes.datos
#
#VentasLunes.obtener_datos()
#
#analizador_ventas_Lunes = AnalizadorVentas(VentasLunes)
#
#analizador_ventas_Lunes.datos
#
#analizador_ventas_Lunes.obtener_ventas_totales()
#
#vv = VisualizadorVentas(VentasLunes)
#
#vv.graficar_ventas_totales1()
#
#vv.graficar_ventas_totales2()
#
#vv.graficar_ventas_totales3()
#
#vv.graficar_ventas_promedio_por_mes()
#
#vv.graficar_productos_mas_vendidos(2)
#
#vv.graficar_mapa_ventas()
#
#ruta_archivo = 'datos_ventas.csv'
#datos = pd.read_csv(ruta_archivo, sep=",", encoding='')
#datos
#
#datos_por_pais = datos.groupby('País')['Ventas'].sum().reset_index()
#datos_por_pais
#
#data_pais = np.array([datos_por_pais.Ventas])
#data_pais
#
#data_pais.shape[0]
#
#data_pais.shape[1]
#
#data_pais.shape
# Out:
#          Fecha    Producto    País  Ventas  Mes   Año
# 0   2022-02-17  Producto 1  País 2    5137    2  2022
# 1   2022-06-19  Producto 2  País 3    3696    6  2022
# 2   2022-08-21  Producto 2  País 2     923    8  2022
# 3   2022-07-17  Producto 1  País 2    3208    7  2022
# 4   2022-06-05  Producto 1  País 2    7795    6  2022
# ..         ...         ...     ...     ...  ...   ...
# 995 2022-07-28  Producto 1  País 1    6715    7  2022
# 996 2022-05-24  Producto 2  País 2    2148    5  2022
# 997 2022-05-18  Producto 1  País 1    8782    5  2022
# 998 2022-12-23  Producto 2  País 2    8314   12  2022
# 999 2022-07-11  Producto 1  País 1    7464    7  2022
#
# [1000 rows x 6 columns]

# %% [markdown]
# Añadir una clase para generar resumen de ventas en la aplicación de ventas que venimos desarrollando durante el tercer trimestre.
#
# código para la clase GeneradorResumenVentas

# %%
class GeneradorResumenVentas:
   def __init__(self, datos_ventas):
       #usamos el dataframe y llamamos al metodo .obtener_datos()
       #para acceder a sus indices y buscar el parametro de la lista 
       #de años. Sino colocamos nada nos aparecera 'DatosVentas' object is not subscriptable
       self.datos = datos_ventas.obtener_datos()

#espera como parametro las palabras: mensual, anual, diario
   def generar_resumen(self, periodo, años=None, mes=None):
       if periodo == "mensual":
           #del dataframe selecciona el parametro de año y busca ese año en la serie 'Año'
           #Agrupa esos nuevos datos por año y mes y suma las ventas 
           #el resultado lo guarda en resumen (PERO LOS DATOS TODAVÍA NO ESTÁN ESCRITO EN EL FICHERO TXT)
           resumen = self.datos[self.datos['Año'].isin(años)].groupby(['Año', 'Mes'])['Ventas'].sum().reset_index()

           #CREAMOS EL TXT VACIO 
           nombre_archivo = "resumen_ventas_mensual.txt"
       
       elif periodo == "anual":
           resumen = self.datos[self.datos['Año'].isin(años)].groupby(['Año'])['Ventas'].sum().reset_index()
           nombre_archivo = "resumen_ventas_anual.txt"
       
       #si periodo es diario y mes tiene valor entonces
       elif periodo == "diario" and mes is not None:
           #selecciono dataframe con la columna años y mes, agrupo por año, mes, 
           # fecha y creo otro dataframe en resumen (sin sumarlas)
           resumen = self.datos[(self.datos['Año'].isin(años)) & (self.datos['Mes'] == mes)].groupby(['Año', 'Mes', 'Fecha'])['Ventas'].sum().reset_index()
           
           #creo el archivo con el mes puesto por parametro
           nombre_archivo = f"resumen_ventas_diario_{mes}.txt"
       
       #si el primer parametro no está dentro de las palabras 
       #mensual, anual, diario salta a este else
       else:
           print("Periodo no válido. Debe ser 'mensual', 'anual' o 'diario' (con un mes especificado).")
           return


        #escribimos el archivo creado, segun la condicion de arriba
       with open(nombre_archivo, 'w') as archivo:
           #como periodo es entero cambiamos a cadena y hacemos salto de linea
           archivo.write("Resumen de ventas " + str(periodo) + "\n")
           archivo.write("###########################################" + "\n")
           archivo.write("\n")
           if años != None:
               archivo.write("años: " + str(años) + ":\n")
           if mes != None:
               archivo.write("mes: " + str(mes) + ":\n")
           archivo.write("--------------------------------------------" + "\n")
           archivo.write("\n")

           #aqui escribe la suma de ventas

           """
           La línea de código archivo.write(resumen.to_string(index=False)) escribe en 
           el archivo de resumen de ventas el contenido del DataFrame resumen 
           convertido en una cadena de texto.

            resumen.to_string(index=False) convierte el DataFrame resumen en una 
            representación en formato de cadena de texto, donde index=False indica 
            que no se incluirá la columna de índices en la representación. 
            Esto significa que el resultado no mostrará los números de fila 
            en la cadena de texto generada.

            Luego, archivo.write() se utiliza para escribir esa cadena de texto 
            en el archivo de resumen de ventas. De esta manera, los datos resumidos 
            se guardan en el archivo en un formato legible.
           """
           archivo.write(resumen.to_string(index=False))

        #toma una lista de valores y los convierte en una cadena de texto donde los 
        # elementos están separados por comas y espacios.
       print(f"¡Se ha generado el archivo de resumen de ventas {periodo} para los años {', '.join(map(str, años))}!")

# %%
datos_ventas = DatosVentas('datos_ventas.csv')
datos_ventas.procesar_datos()


generador_resumen = GeneradorResumenVentas(datos_ventas)


# Generar resumen mensual para los años 2021 y 2022
#generador_resumen.generar_resumen("mensual", [2021, 2022])


# Generar resumen anual para los años 2020, 2021 y 2022
#generador_resumen.generar_resumen("anual", [2020, 2021, 2022])


# Generar resumen diario para el mes de enero de 2023
#generador_resumen.generar_resumen("diario", [2022], mes=1)

#PRUEBAS MIAS 
generador_resumen.generar_resumen("diario", [2022], mes= 2)
# Out:
# ¡Se ha generado el archivo de resumen de ventas diario para los años 2022!

# %%
import sqlite3

class bd_ventas:
    #datos_ventas: dataframe, nombre_base_datos: nombre de la bd 
    def __init__(self, datos_ventas, nombre_base_datos):
        self.datos_ventas = datos_ventas
        self.nombre_base_datos = nombre_base_datos

    def guardar_datos(self):
        # Establecer conexión con la base de datos
        conexion = sqlite3.connect(self.nombre_base_datos)
        cursor = conexion.cursor()

        # Crear la tabla en la base de datos
        cursor.execute('''CREATE TABLE IF NOT EXISTS ventas (
                            Fecha date,
                            Producto varchar2(50),
                            País varchar2(50),
                            Ventas number(5,2)
                        )''')

        # Insertar los datos en la tabla
        for indice, fila in self.datos_ventas.iterrows():
            cursor.execute("INSERT INTO ventas VALUES (?, ?, ?, ?)",
                           (fila['Fecha'], fila['Producto'], fila['País'], fila['Ventas']))

        # Confirmar los cambios
        conexion.commit()

        # Cerrar la conexión
        cursor.close()
        conexion.close()

        print("¡Los datos han sido guardados en la base de datos SQLite!")

    def mostrar_consulta(self):
        conexion= sqlite3.connect('datos_ventas.db')
        cursor= conexion.cursor()
        
        #consulta
        cursor.execute('SELECT * FROM ventas')
        
        tabla= cursor.fetchall()

        for valor in tabla:
            print (valor)
        conexion.close()

# %%
# Ejemplo de uso
datos_ventas = pd.read_csv('datos_ventas.csv')
guardador = bd_ventas(datos_ventas, 'datos_ventas.db')
guardador.guardar_datos()

#categorias= cursor.execute("SELECT * FROM categoria").fetchall()


guardador.mostrar_consulta()
# Out:
# ¡Los datos han sido guardados en la base de datos SQLite!
# ('2022-11-06', 'Producto 2', 'País 2', 1338)
# ('2022-09-15', 'Producto 1', 'País 2', 384)
# ('2022-12-04', 'Producto 2', 'País 1', 6775)
# ('2022-06-26', 'Producto 3', 'País 3', 1048)
# ('2022-01-25', 'Producto 3', 'País 1', 4822)
# ('2022-06-10', 'Producto 2', 'País 3', 3502)
# ('2022-09-08', 'Producto 3', 'País 3', 3335)
# ('2022-08-14', 'Producto 2', 'País 1', 7040)
# ('2022-11-12', 'Producto 1', 'País 3', 1754)
# ('2022-08-25', 'Producto 2', 'País 2', 7259)
# ('2022-10-22', 'Producto 2', 'País 2', 9824)
# ('2022-12-17', 'Producto 3', 'País 1', 4749)
# ('2022-10-15', 'Producto 3', 'País 2', 9728)
# ('2022-10-01', 'Producto 2', 'País 2', 1492)
# ('2022-06-06', 'Producto 3', 'País 1', 1691)
# ('2022-01-28', 'Producto 2', 'País 1', 4586)
# ('2022-05-15', 'Producto 2', 'País 3', 4126)
# ('2022-05-06', 'Producto 3', 'País 2', 5503)
# ('2022-01-08', 'Producto 1', 'País 1', 874)
# ('2022-11-10', 'Producto 1', 'País 1', 3723)
# ('2022-03-05', 'Producto 3', 'País 1', 8067)
# ('2022-07-24', 'Producto 2', 'País 1', 3286)
# ('2022-04-05', 'Producto 1', 'País 2', 2352)
# ('2022-09-22', 'Producto 2', 'País 2', 9250)
# ('2022-12-28', 'Producto 3', 'País 2', 7389)
# ('2022-04-10', 'Producto 1', 'País 1', 3988)
# ('2022-06-17', 'Producto 3', 'País 1', 4916)
# ('2022-10-16', 'Producto 3', 'País 1', 3561)
# ('2022-11-11', 'Producto 3', 'País 3', 8692)
# ('2022-10-06', 'Producto 2', 'País 3', 2904)
# ('2022-10-02', 'Producto 3', 'País 3', 5438)
# ('2022-02-08', 'Producto 3', 'País 2', 6954)
# ('2022-07-04', 'Producto 1', 'País 3', 4995)
# ('2022-05-20', 'Producto 3', 'País 3', 9263)
# ('2022-07-02', 'Producto 1', 'País 2', 290)
# ('2022-07-18', 'Producto 3', 'País 3', 9276)
# ('2022-12-01', 'Producto 2', 'País 2', 4245)
# ('2022-02-26', 'Producto 1', 'País 3', 9902)
# ('2022-10-07', 'Producto 2', 'País 2', 3672)
# ('2022-06-09', 'Producto 3', 'País 2', 3256)
# ('2022-06-10', 'Producto 3', 'País 3', 2780)
# ('2022-11-25', 'Producto 2', 'País 2', 7139)
# ('2022-04-04', 'Producto 3', 'País 3', 2388)
# ('2022-05-04', 'Producto 1', 'País 1', 5469)
# ('2022-09-08', 'Producto 2', 'País 1', 4604)
# ('2022-06-28', 'Producto 2', 'País 1', 2554)
# ('2022-11-16', 'Producto 2', 'País 3', 5629)
# ('2022-04-06', 'Producto 3', 'País 1', 5480)
# ('2022-09-25', 'Producto 3', 'País 3', 1924)
# ('2022-01-22', 'Producto 3', 'País 1', 1004)
# ('2022-10-19', 'Producto 1', 'País 3', 4380)
# ('2022-09-10', 'Producto 1', 'País 1', 2024)
# ('2022-03-26', 'Producto 1', 'País 1', 976)
# ('2022-10-27', 'Producto 1', 'País 1', 3361)
# ('2022-03-08', 'Producto 2', 'País 1', 7471)
# ('2022-12-04', 'Producto 2', 'País 2', 3106)
# ('2022-04-01', 'Producto 2', 'País 3', 5125)
# ('2022-08-19', 'Producto 2', 'País 1', 6645)
# ('2022-10-22', 'Producto 2', 'País 1', 1965)
# ('2022-10-04', 'Producto 2', 'País 3', 4383)
# ('2022-04-11', 'Producto 3', 'País 1', 3563)
# ('2022-03-22', 'Producto 1', 'País 1', 9468)
# ('2022-04-14', 'Producto 2', 'País 3', 6039)
# ('2022-06-05', 'Producto 2', 'País 1', 8276)
# ('2022-03-27', 'Producto 2', 'País 3', 829)
# ('2022-11-12', 'Producto 1', 'País 3', 2287)
# ('2022-06-25', 'Producto 1', 'País 3', 9633)
# ('2022-09-08', 'Producto 2', 'País 2', 1671)
# ('2022-06-03', 'Producto 2', 'País 3', 8338)
# ('2022-05-22', 'Producto 3', 'País 3', 2083)
# ('2022-07-25', 'Producto 1', 'País 3', 7136)
# ('2022-01-28', 'Producto 1', 'País 2', 5647)
# ('2022-09-14', 'Producto 2', 'País 1', 3333)
# ('2022-04-23', 'Producto 3', 'País 1', 3979)
# ('2022-10-01', 'Producto 2', 'País 3', 474)
# ('2022-06-04', 'Producto 2', 'País 1', 6753)
# ('2022-05-18', 'Producto 1', 'País 3', 6730)
# ('2022-05-08', 'Producto 1', 'País 3', 121)
# ('2022-02-08', 'Producto 1', 'País 1', 9693)
# ('2022-01-16', 'Producto 1', 'País 3', 2566)
# ('2022-12-25', 'Producto 3', 'País 2', 9335)
# ('2022-07-15', 'Producto 3', 'País 1', 249)
# ('2022-02-25', 'Producto 2', 'País 2', 1207)
# ('2022-02-02', 'Producto 3', 'País 3', 4414)
# ('2022-05-01', 'Producto 3', 'País 2', 6985)
# ('2022-11-12', 'Producto 2', 'País 3', 7358)
# ('2022-03-18', 'Producto 1', 'País 3', 3184)
# ('2022-01-27', 'Producto 3', 'País 2', 3341)
# ('2022-04-06', 'Producto 3', 'País 3', 2428)
# ('2022-09-18', 'Producto 2', 'País 1', 6116)
# ('2022-09-06', 'Producto 3', 'País 2', 8434)
# ('2022-08-07', 'Producto 1', 'País 1', 1979)
# ('2022-04-05', 'Producto 3', 'País 3', 6090)
# ('2022-08-02', 'Producto 3', 'País 2', 7267)
# ('2022-01-21', 'Producto 1', 'País 3', 1167)
# ('2022-11-13', 'Producto 3', 'País 2', 6630)
# ('2022-08-23', 'Producto 1', 'País 1', 5147)
# ('2022-10-19', 'Producto 1', 'País 3', 1643)
# ('2022-05-23', 'Producto 3', 'País 1', 6966)
# ('2022-05-17', 'Producto 1', 'País 2', 4056)
# ('2022-06-24', 'Producto 2', 'País 1', 5110)
# ('2022-09-12', 'Producto 2', 'País 3', 5441)
# ('2022-06-18', 'Producto 3', 'País 3', 6136)
# ('2022-07-20', 'Producto 3', 'País 3', 6882)
# ('2022-11-21', 'Producto 1', 'País 1', 6725)
# ('2022-03-10', 'Producto 3', 'País 2', 2250)
# ('2022-05-27', 'Producto 1', 'País 2', 5837)
# ('2022-04-26', 'Producto 2', 'País 3', 5044)
# ('2022-11-16', 'Producto 2', 'País 1', 136)
# ('2022-07-23', 'Producto 1', 'País 2', 2637)
# ('2022-01-11', 'Producto 1', 'País 3', 7999)
# ('2022-01-25', 'Producto 3', 'País 2', 1749)
# ('2022-06-15', 'Producto 2', 'País 1', 6139)
# ('2022-07-01', 'Producto 2', 'País 1', 5804)
# ('2022-09-01', 'Producto 3', 'País 2', 9347)
# ('2022-11-05', 'Producto 3', 'País 3', 1571)
# ('2022-12-15', 'Producto 2', 'País 1', 1766)
# ('2022-11-24', 'Producto 3', 'País 1', 8387)
# ('2022-01-10', 'Producto 3', 'País 3', 1464)
# ('2022-07-09', 'Producto 1', 'País 2', 5030)
# ('2022-06-02', 'Producto 2', 'País 3', 7891)
# ('2022-02-20', 'Producto 3', 'País 3', 9101)
# ('2022-10-12', 'Producto 3', 'País 3', 587)
# ('2022-09-26', 'Producto 1', 'País 2', 1437)
# ('2022-02-12', 'Producto 1', 'País 3', 1538)
# ('2022-05-08', 'Producto 1', 'País 2', 3502)
# ('2022-03-27', 'Producto 1', 'País 1', 6757)
# ('2022-11-15', 'Producto 2', 'País 1', 9412)
# ('2022-02-07', 'Producto 3', 'País 1', 1049)
# ('2022-01-04', 'Producto 3', 'País 3', 1944)
# ('2022-05-27', 'Producto 3', 'País 1', 8666)
# ('2022-09-07', 'Producto 2', 'País 3', 2009)
# ('2022-05-16', 'Producto 2', 'País 3', 866)
# ('2022-08-06', 'Producto 2', 'País 3', 7214)
# ('2022-02-06', 'Producto 1', 'País 3', 5335)
# ('2022-09-23', 'Producto 1', 'País 3', 7341)
# ('2022-04-18', 'Producto 1', 'País 1', 3876)
# ('2022-06-07', 'Producto 2', 'País 1', 9177)
# ('2022-01-10', 'Producto 1', 'País 2', 1591)
# ('2022-06-19', 'Producto 3', 'País 2', 5771)
# ('2022-04-19', 'Producto 3', 'País 2', 5331)
# ('2022-06-28', 'Producto 2', 'País 3', 8244)
# ('2022-01-03', 'Producto 3', 'País 1', 6946)
# ('2022-12-11', 'Producto 2', 'País 1', 2836)
# ('2022-11-12', 'Producto 2', 'País 2', 5236)
# ('2022-03-17', 'Producto 3', 'País 2', 1026)
# ('2022-01-23', 'Producto 2', 'País 3', 1199)
# ('2022-10-07', 'Producto 3', 'País 1', 5686)
# ('2022-10-19', 'Producto 2', 'País 3', 3832)
# ('2022-02-13', 'Producto 2', 'País 2', 6153)
# ('2022-08-23', 'Producto 3', 'País 2', 579)
# ('2022-04-19', 'Producto 3', 'País 2', 2355)
# ('2022-09-22', 'Producto 3', 'País 1', 8916)
# ('2022-05-13', 'Producto 2', 'País 3', 7111)
# ('2022-10-10', 'Producto 3', 'País 2', 3620)
# ('2022-09-03', 'Producto 3', 'País 2', 937)
# ('2022-04-19', 'Producto 2', 'País 2', 9076)
# ('2022-05-18', 'Producto 3', 'País 1', 4607)
# ('2022-04-25', 'Producto 2', 'País 1', 9473)
# ('2022-07-25', 'Producto 1', 'País 3', 2239)
# ('2022-08-26', 'Producto 2', 'País 1', 6429)
# ('2022-03-07', 'Producto 2', 'País 1', 4909)
# ('2022-08-28', 'Producto 2', 'País 1', 5160)
# ('2022-07-03', 'Producto 2', 'País 3', 7568)
# ('2022-10-25', 'Producto 2', 'País 1', 4779)
# ('2022-06-08', 'Producto 3', 'País 2', 6861)
# ('2022-10-13', 'Producto 1', 'País 2', 2874)
# ('2022-03-03', 'Producto 1', 'País 1', 4855)
# ('2022-01-15', 'Producto 1', 'País 3', 4180)
# ('2022-05-16', 'Producto 1', 'País 1', 6346)
# ('2022-09-27', 'Producto 2', 'País 2', 6285)
# ('2022-04-04', 'Producto 3', 'País 3', 5748)
# ('2022-10-13', 'Producto 1', 'País 2', 3910)
# ('2022-10-14', 'Producto 3', 'País 2', 8556)
# ('2022-08-24', 'Producto 2', 'País 1', 6518)
# ('2022-03-13', 'Producto 2', 'País 2', 6227)
# ('2022-12-14', 'Producto 2', 'País 2', 7992)
# ('2022-11-01', 'Producto 3', 'País 2', 6930)
# ('2022-10-28', 'Producto 2', 'País 3', 1803)
# ('2022-07-21', 'Producto 1', 'País 3', 648)
# ('2022-05-05', 'Producto 2', 'País 2', 2843)
# ('2022-03-10', 'Producto 3', 'País 2', 5817)
# ('2022-04-04', 'Producto 3', 'País 2', 8845)
# ('2022-08-25', 'Producto 2', 'País 1', 3207)
# ('2022-02-05', 'Producto 2', 'País 3', 4920)
# ('2022-04-10', 'Producto 3', 'País 1', 7337)
# ('2022-12-06', 'Producto 1', 'País 1', 272)
# ('2022-07-11', 'Producto 1', 'País 2', 5244)
# ('2022-04-18', 'Producto 2', 'País 3', 6341)
# ('2022-08-14', 'Producto 2', 'País 1', 544)
# ('2022-12-28', 'Producto 2', 'País 1', 101)
# ('2022-03-05', 'Producto 2', 'País 3', 6616)
# ('2022-04-14', 'Producto 2', 'País 3', 9688)
# ('2022-08-13', 'Producto 2', 'País 3', 3573)
# ('2022-10-03', 'Producto 1', 'País 2', 5409)
# ('2022-07-09', 'Producto 3', 'País 2', 9369)
# ('2022-03-10', 'Producto 3', 'País 3', 9722)
# ('2022-10-05', 'Producto 1', 'País 1', 9805)
# ('2022-01-18', 'Producto 2', 'País 1', 268)
# ('2022-03-27', 'Producto 1', 'País 1', 3863)
# ('2022-03-04', 'Producto 2', 'País 1', 7378)
# ('2022-05-18', 'Producto 1', 'País 3', 1825)
# ('2022-11-08', 'Producto 1', 'País 2', 8975)
# ('2022-08-06', 'Producto 1', 'País 2', 9841)
# ('2022-03-10', 'Producto 2', 'País 2', 3727)
# ('2022-06-13', 'Producto 1', 'País 3', 5429)
# ('2022-07-08', 'Producto 3', 'País 2', 5978)
# ('2022-11-14', 'Producto 2', 'País 1', 8467)
# ('2022-01-11', 'Producto 3', 'País 1', 7708)
# ('2022-06-13', 'Producto 1', 'País 1', 3641)
# ('2022-07-18', 'Producto 1', 'País 2', 2938)
# ('2022-11-02', 'Producto 2', 'País 1', 5863)
# ('2022-07-20', 'Producto 1', 'País 2', 5821)
# ('2022-01-14', 'Producto 3', 'País 2', 8719)
# ('2022-07-09', 'Producto 1', 'País 3', 259)
# ('2022-11-04', 'Producto 3', 'País 2', 2765)
# ('2022-06-03', 'Producto 1', 'País 1', 4766)
# ('2022-01-27', 'Producto 3', 'País 1', 6891)
# ('2022-03-04', 'Producto 3', 'País 1', 2686)
# ('2022-10-03', 'Producto 1', 'País 1', 1253)
# ('2022-07-18', 'Producto 1', 'País 1', 4575)
# ('2022-04-21', 'Producto 2', 'País 3', 6341)
# ('2022-09-26', 'Producto 3', 'País 2', 4155)
# ('2022-07-15', 'Producto 1', 'País 2', 6949)
# ('2022-06-18', 'Producto 2', 'País 1', 4535)
# ('2022-11-19', 'Producto 3', 'País 1', 1639)
# ('2022-10-11', 'Producto 1', 'País 1', 8341)
# ('2022-09-03', 'Producto 3', 'País 3', 1687)
# ('2022-03-07', 'Producto 3', 'País 1', 552)
# ('2022-05-10', 'Producto 2', 'País 1', 7466)
# ('2022-11-05', 'Producto 1', 'País 3', 2747)
# ('2022-04-27', 'Producto 1', 'País 3', 9596)
# ('2022-10-22', 'Producto 2', 'País 2', 7843)
# ('2022-11-24', 'Producto 1', 'País 1', 8353)
# ('2022-08-24', 'Producto 1', 'País 3', 9342)
# ('2022-10-07', 'Producto 3', 'País 2', 6890)
# ('2022-01-19', 'Producto 2', 'País 2', 608)
# ('2022-07-20', 'Producto 2', 'País 2', 9150)
# ('2022-08-04', 'Producto 2', 'País 1', 9504)
# ('2022-12-02', 'Producto 3', 'País 3', 2808)
# ('2022-08-01', 'Producto 3', 'País 3', 2084)
# ('2022-02-23', 'Producto 1', 'País 2', 1326)
# ('2022-03-09', 'Producto 1', 'País 2', 6364)
# ('2022-04-09', 'Producto 3', 'País 1', 7348)
# ('2022-10-06', 'Producto 3', 'País 3', 6610)
# ('2022-03-07', 'Producto 2', 'País 2', 7870)
# ('2022-07-10', 'Producto 3', 'País 1', 1623)
# ('2022-08-18', 'Producto 1', 'País 1', 5414)
# ('2022-05-28', 'Producto 1', 'País 2', 9450)
# ('2022-02-21', 'Producto 1', 'País 1', 996)
# ('2022-06-22', 'Producto 2', 'País 2', 2474)
# ('2022-02-05', 'Producto 1', 'País 3', 2854)
# ('2022-12-28', 'Producto 3', 'País 3', 8721)
# ('2022-03-01', 'Producto 1', 'País 2', 6839)
# ('2022-01-23', 'Producto 3', 'País 3', 7651)
# ('2022-07-10', 'Producto 1', 'País 3', 1956)
# ('2022-07-01', 'Producto 1', 'País 3', 8100)
# ('2022-04-09', 'Producto 1', 'País 2', 5306)
# ('2022-12-08', 'Producto 2', 'País 3', 6033)
# ('2022-04-21', 'Producto 1', 'País 1', 9718)
# ('2022-08-23', 'Producto 3', 'País 3', 3032)
# ('2022-12-10', 'Producto 1', 'País 3', 4450)
# ('2022-04-02', 'Producto 3', 'País 3', 6872)
# ('2022-11-24', 'Producto 2', 'País 1', 6638)
# ('2022-11-25', 'Producto 1', 'País 2', 7824)
# ('2022-01-28', 'Producto 3', 'País 3', 1875)
# ('2022-03-06', 'Producto 1', 'País 2', 2790)
# ('2022-07-01', 'Producto 2', 'País 2', 4924)
# ('2022-04-05', 'Producto 2', 'País 1', 2755)
# ('2022-08-07', 'Producto 3', 'País 1', 3404)
# ('2022-12-16', 'Producto 1', 'País 3', 4588)
# ('2022-10-17', 'Producto 3', 'País 1', 9942)
# ('2022-08-20', 'Producto 1', 'País 1', 1358)
# ('2022-07-03', 'Producto 2', 'País 1', 8349)
# ('2022-01-17', 'Producto 2', 'País 3', 6238)
# ('2022-05-17', 'Producto 2', 'País 2', 2138)
# ('2022-01-15', 'Producto 3', 'País 1', 2356)
# ('2022-08-14', 'Producto 1', 'País 1', 7348)
# ('2022-07-14', 'Producto 2', 'País 2', 3845)
# ('2022-11-08', 'Producto 2', 'País 3', 1909)
# ('2022-07-21', 'Producto 3', 'País 3', 8993)
# ('2022-06-01', 'Producto 3', 'País 1', 5046)
# ('2022-07-09', 'Producto 3', 'País 2', 8726)
# ('2022-04-22', 'Producto 3', 'País 1', 2047)
# ('2022-05-26', 'Producto 2', 'País 2', 8726)
# ('2022-06-23', 'Producto 3', 'País 2', 4173)
# ('2022-11-14', 'Producto 1', 'País 2', 5946)
# ('2022-02-19', 'Producto 3', 'País 3', 7716)
# ('2022-05-22', 'Producto 1', 'País 2', 2105)
# ('2022-05-20', 'Producto 3', 'País 2', 8949)
# ('2022-05-07', 'Producto 1', 'País 3', 550)
# ('2022-01-09', 'Producto 2', 'País 2', 937)
# ('2022-04-10', 'Producto 2', 'País 1', 9771)
# ('2022-06-01', 'Producto 2', 'País 3', 3221)
# ('2022-04-07', 'Producto 2', 'País 2', 1317)
# ('2022-11-14', 'Producto 2', 'País 2', 6316)
# ('2022-03-03', 'Producto 3', 'País 1', 3338)
# ('2022-03-04', 'Producto 3', 'País 1', 829)
# ('2022-04-13', 'Producto 3', 'País 1', 1692)
# ('2022-02-18', 'Producto 1', 'País 3', 1317)
# ('2022-11-06', 'Producto 1', 'País 2', 8925)
# ('2022-04-20', 'Producto 2', 'País 2', 9461)
# ('2022-02-22', 'Producto 1', 'País 1', 8181)
# ('2022-11-28', 'Producto 3', 'País 2', 2371)
# ('2022-12-18', 'Producto 2', 'País 2', 8422)
# ('2022-01-10', 'Producto 3', 'País 1', 759)
# ('2022-09-26', 'Producto 1', 'País 3', 2997)
# ('2022-11-26', 'Producto 1', 'País 3', 7205)
# ('2022-01-25', 'Producto 1', 'País 2', 2019)
# ('2022-08-14', 'Producto 1', 'País 2', 8008)
# ('2022-08-28', 'Producto 3', 'País 2', 4890)
# ('2022-10-19', 'Producto 3', 'País 1', 3338)
# ('2022-09-21', 'Producto 1', 'País 1', 9886)
# ('2022-01-05', 'Producto 2', 'País 3', 8272)
# ('2022-01-16', 'Producto 1', 'País 1', 3675)
# ('2022-07-22', 'Producto 3', 'País 1', 6485)
# ('2022-01-18', 'Producto 2', 'País 3', 627)
# ('2022-06-18', 'Producto 2', 'País 1', 9423)
# ('2022-07-24', 'Producto 3', 'País 3', 4574)
# ('2022-05-12', 'Producto 2', 'País 1', 8471)
# ('2022-07-28', 'Producto 2', 'País 1', 3288)
# ('2022-05-12', 'Producto 3', 'País 1', 5531)
# ('2022-08-02', 'Producto 1', 'País 2', 8198)
# ('2022-09-14', 'Producto 2', 'País 3', 3476)
# ('2022-12-03', 'Producto 2', 'País 3', 8912)
# ('2022-11-08', 'Producto 3', 'País 1', 985)
# ('2022-08-06', 'Producto 3', 'País 1', 4539)
# ('2022-12-18', 'Producto 2', 'País 2', 7613)
# ('2022-12-17', 'Producto 1', 'País 2', 8372)
# ('2022-11-17', 'Producto 2', 'País 1', 3977)
# ('2022-09-05', 'Producto 1', 'País 1', 8794)
# ('2022-04-14', 'Producto 2', 'País 3', 3275)
# ('2022-05-14', 'Producto 3', 'País 2', 7810)
# ('2022-12-03', 'Producto 2', 'País 2', 4402)
# ('2022-03-02', 'Producto 2', 'País 3', 3478)
# ('2022-09-14', 'Producto 2', 'País 3', 4825)
# ('2022-10-20', 'Producto 3', 'País 3', 2981)
# ('2022-09-13', 'Producto 2', 'País 2', 9710)
# ('2022-05-09', 'Producto 1', 'País 1', 5187)
# ('2022-08-28', 'Producto 1', 'País 1', 8241)
# ('2022-09-18', 'Producto 1', 'País 3', 246)
# ('2022-09-04', 'Producto 3', 'País 2', 8625)
# ('2022-01-09', 'Producto 2', 'País 2', 6634)
# ('2022-02-16', 'Producto 2', 'País 3', 3547)
# ('2022-02-03', 'Producto 1', 'País 1', 1671)
# ('2022-05-24', 'Producto 3', 'País 1', 814)
# ('2022-03-24', 'Producto 1', 'País 3', 933)
# ('2022-05-23', 'Producto 1', 'País 1', 8226)
# ('2022-04-23', 'Producto 1', 'País 1', 8084)
# ('2022-06-18', 'Producto 2', 'País 2', 8077)
# ('2022-10-06', 'Producto 2', 'País 1', 5614)
# ('2022-10-09', 'Producto 1', 'País 3', 7847)
# ('2022-01-11', 'Producto 1', 'País 3', 4192)
# ('2022-09-25', 'Producto 2', 'País 2', 8683)
# ('2022-07-11', 'Producto 1', 'País 2', 4833)
# ('2022-04-27', 'Producto 1', 'País 1', 8726)
# ('2022-11-20', 'Producto 3', 'País 1', 5263)
# ('2022-09-09', 'Producto 1', 'País 2', 3889)
# ('2022-07-20', 'Producto 2', 'País 2', 8957)
# ('2022-01-21', 'Producto 2', 'País 2', 8352)
# ('2022-08-22', 'Producto 1', 'País 3', 6277)
# ('2022-06-07', 'Producto 2', 'País 3', 8234)
# ('2022-11-17', 'Producto 3', 'País 3', 5555)
# ('2022-02-22', 'Producto 3', 'País 2', 1210)
# ('2022-01-27', 'Producto 1', 'País 2', 2817)
# ('2022-11-28', 'Producto 1', 'País 3', 875)
# ('2022-01-10', 'Producto 3', 'País 1', 1180)
# ('2022-08-03', 'Producto 1', 'País 3', 7131)
# ('2022-06-11', 'Producto 1', 'País 1', 3043)
# ('2022-02-13', 'Producto 3', 'País 1', 9596)
# ('2022-07-02', 'Producto 3', 'País 1', 6805)
# ('2022-08-26', 'Producto 2', 'País 1', 5217)
# ('2022-09-01', 'Producto 1', 'País 3', 3620)
# ('2022-06-21', 'Producto 1', 'País 2', 3724)
# ('2022-12-12', 'Producto 1', 'País 2', 3424)
# ('2022-05-22', 'Producto 3', 'País 2', 7043)
# ('2022-08-06', 'Producto 1', 'País 1', 7706)
# ('2022-11-19', 'Producto 1', 'País 1', 797)
# ('2022-03-17', 'Producto 2', 'País 2', 8606)
# ('2022-09-13', 'Producto 1', 'País 1', 7487)
# ('2022-04-13', 'Producto 2', 'País 1', 4700)
# ('2022-06-06', 'Producto 1', 'País 2', 5195)
# ('2022-02-25', 'Producto 3', 'País 1', 5643)
# ('2022-01-20', 'Producto 1', 'País 1', 7969)
# ('2022-09-17', 'Producto 2', 'País 1', 3653)
# ('2022-04-18', 'Producto 2', 'País 2', 1127)
# ('2022-12-07', 'Producto 1', 'País 3', 6936)
# ('2022-10-23', 'Producto 2', 'País 2', 3188)
# ('2022-03-10', 'Producto 3', 'País 2', 9654)
# ('2022-11-11', 'Producto 1', 'País 1', 6458)
# ('2022-02-23', 'Producto 1', 'País 3', 6065)
# ('2022-02-02', 'Producto 1', 'País 2', 2397)
# ('2022-04-19', 'Producto 1', 'País 2', 3676)
# ('2022-03-10', 'Producto 2', 'País 1', 3467)
# ('2022-09-26', 'Producto 1', 'País 1', 8608)
# ('2022-01-15', 'Producto 2', 'País 1', 8237)
# ('2022-04-16', 'Producto 1', 'País 3', 7196)
# ('2022-03-08', 'Producto 2', 'País 2', 4842)
# ('2022-03-04', 'Producto 3', 'País 3', 6208)
# ('2022-07-20', 'Producto 2', 'País 3', 3607)
# ('2022-10-07', 'Producto 1', 'País 2', 2143)
# ('2022-04-21', 'Producto 3', 'País 3', 1590)
# ('2022-04-05', 'Producto 3', 'País 1', 7497)
# ('2022-08-01', 'Producto 3', 'País 3', 5298)
# ('2022-04-17', 'Producto 1', 'País 2', 9181)
# ('2022-01-01', 'Producto 1', 'País 1', 1909)
# ('2022-03-15', 'Producto 1', 'País 3', 5331)
# ('2022-03-08', 'Producto 1', 'País 2', 1741)
# ('2022-09-11', 'Producto 2', 'País 3', 683)
# ('2022-02-04', 'Producto 3', 'País 3', 7949)
# ('2022-05-21', 'Producto 2', 'País 3', 3871)
# ('2022-09-06', 'Producto 2', 'País 2', 4269)
# ('2022-04-09', 'Producto 1', 'País 3', 3443)
# ('2022-04-21', 'Producto 1', 'País 1', 492)
# ('2022-12-10', 'Producto 3', 'País 2', 429)
# ('2022-02-21', 'Producto 3', 'País 3', 8381)
# ('2022-10-13', 'Producto 3', 'País 2', 2425)
# ('2022-10-09', 'Producto 3', 'País 3', 158)
# ('2022-02-03', 'Producto 2', 'País 2', 1596)
# ('2022-05-21', 'Producto 3', 'País 3', 2282)
# ('2022-06-11', 'Producto 3', 'País 1', 2195)
# ('2022-12-20', 'Producto 2', 'País 1', 5692)
# ('2022-07-02', 'Producto 1', 'País 3', 7688)
# ('2022-10-06', 'Producto 3', 'País 1', 2820)
# ('2022-05-23', 'Producto 3', 'País 2', 842)
# ('2022-03-07', 'Producto 2', 'País 2', 1803)
# ('2022-08-20', 'Producto 2', 'País 3', 7243)
# ('2022-06-21', 'Producto 2', 'País 2', 1260)
# ('2022-04-20', 'Producto 2', 'País 2', 1185)
# ('2022-07-16', 'Producto 3', 'País 1', 9369)
# ('2022-09-03', 'Producto 3', 'País 1', 8474)
# ('2022-11-15', 'Producto 1', 'País 3', 9391)
# ('2022-06-03', 'Producto 3', 'País 3', 8656)
# ('2022-09-11', 'Producto 1', 'País 3', 9274)
# ('2022-03-19', 'Producto 2', 'País 3', 8770)
# ('2022-03-06', 'Producto 2', 'País 1', 7275)
# ('2022-06-02', 'Producto 3', 'País 3', 1474)
# ('2022-12-16', 'Producto 2', 'País 2', 8663)
# ('2022-05-26', 'Producto 3', 'País 3', 3007)
# ('2022-06-01', 'Producto 1', 'País 3', 8398)
# ('2022-07-11', 'Producto 2', 'País 2', 2652)
# ('2022-08-07', 'Producto 1', 'País 1', 521)
# ('2022-11-11', 'Producto 2', 'País 2', 2322)
# ('2022-07-02', 'Producto 3', 'País 2', 4894)
# ('2022-11-05', 'Producto 2', 'País 2', 5638)
# ('2022-06-09', 'Producto 1', 'País 2', 3649)
# ('2022-06-16', 'Producto 1', 'País 2', 8633)
# ('2022-09-27', 'Producto 2', 'País 3', 4445)
# ('2022-10-01', 'Producto 2', 'País 3', 9398)
# ('2022-07-09', 'Producto 2', 'País 2', 4170)
# ('2022-08-26', 'Producto 2', 'País 1', 7547)
# ('2022-04-10', 'Producto 1', 'País 3', 9897)
# ('2022-06-16', 'Producto 3', 'País 1', 1214)
# ('2022-03-20', 'Producto 2', 'País 2', 2990)
# ('2022-12-14', 'Producto 3', 'País 3', 4897)
# ('2022-07-13', 'Producto 2', 'País 1', 2421)
# ('2022-06-24', 'Producto 1', 'País 1', 1261)
# ('2022-10-21', 'Producto 3', 'País 2', 7330)
# ('2022-01-04', 'Producto 3', 'País 3', 6905)
# ('2022-09-10', 'Producto 1', 'País 3', 8962)
# ('2022-02-23', 'Producto 2', 'País 2', 4453)
# ('2022-06-20', 'Producto 3', 'País 2', 4124)
# ('2022-02-15', 'Producto 2', 'País 2', 1540)
# ('2022-07-23', 'Producto 3', 'País 2', 2480)
# ('2022-07-27', 'Producto 1', 'País 1', 2099)
# ('2022-02-01', 'Producto 2', 'País 3', 3089)
# ('2022-09-04', 'Producto 2', 'País 3', 6349)
# ('2022-06-15', 'Producto 3', 'País 2', 7854)
# ('2022-06-19', 'Producto 1', 'País 2', 2222)
# ('2022-02-16', 'Producto 1', 'País 2', 2444)
# ('2022-02-17', 'Producto 2', 'País 1', 2987)
# ('2022-09-14', 'Producto 3', 'País 1', 4545)
# ('2022-03-04', 'Producto 1', 'País 1', 3373)
# ('2022-11-02', 'Producto 2', 'País 1', 3921)
# ('2022-10-07', 'Producto 1', 'País 3', 9290)
# ('2022-07-25', 'Producto 2', 'País 1', 6642)
# ('2022-05-14', 'Producto 3', 'País 1', 5864)
# ('2022-12-27', 'Producto 1', 'País 1', 7378)
# ('2022-07-19', 'Producto 3', 'País 3', 5278)
# ('2022-12-24', 'Producto 1', 'País 3', 3995)
# ('2022-12-13', 'Producto 2', 'País 2', 9546)
# ('2022-04-25', 'Producto 2', 'País 2', 5665)
# ('2022-09-01', 'Producto 1', 'País 2', 7576)
# ('2022-03-27', 'Producto 3', 'País 3', 9124)
# ('2022-03-04', 'Producto 2', 'País 2', 8471)
# ('2022-05-20', 'Producto 1', 'País 1', 3403)
# ('2022-01-01', 'Producto 2', 'País 3', 6676)
# ('2022-10-25', 'Producto 1', 'País 2', 2936)
# ('2022-02-13', 'Producto 3', 'País 3', 7647)
# ('2022-01-12', 'Producto 2', 'País 2', 8577)
# ('2022-01-15', 'Producto 3', 'País 1', 6215)
# ('2022-10-20', 'Producto 3', 'País 3', 4044)
# ('2022-07-01', 'Producto 2', 'País 2', 980)
# ('2022-01-12', 'Producto 1', 'País 2', 9147)
# ('2022-11-22', 'Producto 1', 'País 3', 8369)
# ('2022-10-12', 'Producto 3', 'País 2', 2496)
# ('2022-09-07', 'Producto 1', 'País 2', 8055)
# ('2022-06-16', 'Producto 2', 'País 3', 6669)
# ('2022-01-24', 'Producto 3', 'País 3', 4636)
# ('2022-03-14', 'Producto 1', 'País 3', 6257)
# ('2022-04-13', 'Producto 1', 'País 1', 5020)
# ('2022-01-10', 'Producto 2', 'País 3', 4751)
# ('2022-06-17', 'Producto 1', 'País 2', 8435)
# ('2022-11-27', 'Producto 2', 'País 3', 6273)
# ('2022-08-14', 'Producto 3', 'País 2', 206)
# ('2022-12-22', 'Producto 2', 'País 2', 3572)
# ('2022-08-16', 'Producto 3', 'País 1', 6509)
# ('2022-09-22', 'Producto 2', 'País 3', 5881)
# ('2022-09-11', 'Producto 2', 'País 2', 9340)
# ('2022-05-16', 'Producto 2', 'País 3', 3812)
# ('2022-12-25', 'Producto 2', 'País 2', 2368)
# ('2022-06-07', 'Producto 2', 'País 2', 3257)
# ('2022-01-02', 'Producto 1', 'País 2', 1613)
# ('2022-09-03', 'Producto 2', 'País 2', 2707)
# ('2022-09-21', 'Producto 3', 'País 3', 3083)
# ('2022-02-09', 'Producto 1', 'País 3', 383)
# ('2022-09-26', 'Producto 1', 'País 3', 1696)
# ('2022-02-14', 'Producto 1', 'País 3', 6401)
# ('2022-02-25', 'Producto 3', 'País 1', 4029)
# ('2022-11-10', 'Producto 2', 'País 3', 8533)
# ('2022-10-16', 'Producto 3', 'País 2', 6517)
# ('2022-07-15', 'Producto 2', 'País 2', 4557)
# ('2022-08-08', 'Producto 3', 'País 2', 6205)
# ('2022-09-01', 'Producto 2', 'País 1', 8230)
# ('2022-10-13', 'Producto 2', 'País 3', 8789)
# ('2022-01-03', 'Producto 3', 'País 3', 4559)
# ('2022-12-25', 'Producto 2', 'País 1', 5394)
# ('2022-12-21', 'Producto 1', 'País 1', 2656)
# ('2022-09-22', 'Producto 1', 'País 1', 3453)
# ('2022-11-12', 'Producto 2', 'País 1', 3639)
# ('2022-12-16', 'Producto 1', 'País 3', 4579)
# ('2022-07-15', 'Producto 2', 'País 1', 7032)
# ('2022-01-01', 'Producto 2', 'País 3', 7561)
# ('2022-07-21', 'Producto 3', 'País 3', 547)
# ('2022-03-16', 'Producto 2', 'País 1', 4464)
# ('2022-11-18', 'Producto 2', 'País 2', 6647)
# ('2022-10-18', 'Producto 3', 'País 3', 5111)
# ('2022-03-23', 'Producto 3', 'País 2', 9517)
# ('2022-01-05', 'Producto 1', 'País 1', 9863)
# ('2022-04-25', 'Producto 1', 'País 3', 6942)
# ('2022-06-16', 'Producto 2', 'País 1', 8991)
# ('2022-02-16', 'Producto 1', 'País 2', 6899)
# ('2022-06-19', 'Producto 2', 'País 2', 788)
# ('2022-10-22', 'Producto 1', 'País 3', 4209)
# ('2022-11-15', 'Producto 1', 'País 2', 2288)
# ('2022-04-12', 'Producto 2', 'País 1', 169)
# ('2022-07-12', 'Producto 1', 'País 2', 2397)
# ('2022-03-23', 'Producto 3', 'País 2', 4966)
# ('2022-07-19', 'Producto 1', 'País 3', 9416)
# ('2022-03-25', 'Producto 2', 'País 1', 9136)
# ('2022-09-13', 'Producto 2', 'País 3', 161)
# ('2022-08-01', 'Producto 1', 'País 2', 9951)
# ('2022-07-25', 'Producto 1', 'País 1', 5589)
# ('2022-09-28', 'Producto 1', 'País 1', 1312)
# ('2022-12-08', 'Producto 2', 'País 2', 6536)
# ('2022-04-26', 'Producto 3', 'País 3', 5665)
# ('2022-05-07', 'Producto 2', 'País 3', 8492)
# ('2022-05-12', 'Producto 1', 'País 2', 4054)
# ('2022-05-24', 'Producto 3', 'País 3', 3430)
# ('2022-10-16', 'Producto 1', 'País 3', 3403)
# ('2022-11-21', 'Producto 1', 'País 2', 9758)
# ('2022-05-13', 'Producto 3', 'País 2', 1746)
# ('2022-05-05', 'Producto 1', 'País 3', 7931)
# ('2022-03-05', 'Producto 3', 'País 1', 2837)
# ('2022-04-20', 'Producto 1', 'País 3', 316)
# ('2022-08-03', 'Producto 3', 'País 2', 174)
# ('2022-10-12', 'Producto 2', 'País 1', 5284)
# ('2022-11-06', 'Producto 1', 'País 2', 4485)
# ('2022-11-24', 'Producto 2', 'País 2', 1039)
# ('2022-02-06', 'Producto 1', 'País 3', 6444)
# ('2022-04-24', 'Producto 2', 'País 3', 5997)
# ('2022-01-15', 'Producto 1', 'País 3', 8211)
# ('2022-02-16', 'Producto 1', 'País 1', 8801)
# ('2022-02-18', 'Producto 2', 'País 2', 118)
# ('2022-05-14', 'Producto 3', 'País 1', 8699)
# ('2022-03-28', 'Producto 3', 'País 2', 3909)
# ('2022-12-08', 'Producto 3', 'País 1', 190)
# ('2022-12-09', 'Producto 3', 'País 1', 3024)
# ('2022-06-04', 'Producto 2', 'País 3', 5838)
# ('2022-07-18', 'Producto 1', 'País 3', 5023)
# ('2022-11-21', 'Producto 2', 'País 2', 6075)
# ('2022-10-14', 'Producto 2', 'País 2', 8917)
# ('2022-10-27', 'Producto 1', 'País 3', 2452)
# ('2022-09-09', 'Producto 1', 'País 1', 3341)
# ('2022-03-05', 'Producto 2', 'País 3', 1045)
# ('2022-12-10', 'Producto 2', 'País 3', 9928)
# ('2022-10-02', 'Producto 3', 'País 2', 7826)
# ('2022-01-16', 'Producto 1', 'País 2', 657)
# ('2022-02-27', 'Producto 1', 'País 2', 2382)
# ('2022-04-18', 'Producto 2', 'País 2', 8436)
# ('2022-09-26', 'Producto 3', 'País 3', 6368)
# ('2022-12-25', 'Producto 2', 'País 1', 6787)
# ('2022-12-09', 'Producto 2', 'País 1', 7450)
# ('2022-11-05', 'Producto 3', 'País 3', 7401)
# ('2022-12-20', 'Producto 1', 'País 3', 7201)
# ('2022-08-11', 'Producto 2', 'País 2', 2777)
# ('2022-02-13', 'Producto 1', 'País 2', 9698)
# ('2022-04-03', 'Producto 3', 'País 1', 9816)
# ('2022-01-18', 'Producto 1', 'País 1', 5617)
# ('2022-10-27', 'Producto 1', 'País 1', 3531)
# ('2022-09-04', 'Producto 1', 'País 1', 2866)
# ('2022-07-01', 'Producto 3', 'País 2', 6504)
# ('2022-09-28', 'Producto 1', 'País 3', 7574)
# ('2022-12-02', 'Producto 2', 'País 3', 3954)
# ('2022-07-25', 'Producto 1', 'País 3', 9068)
# ('2022-04-28', 'Producto 1', 'País 2', 3676)
# ('2022-01-10', 'Producto 3', 'País 3', 1241)
# ('2022-02-04', 'Producto 1', 'País 3', 2641)
# ('2022-10-28', 'Producto 3', 'País 3', 6972)
# ('2022-12-26', 'Producto 1', 'País 2', 9856)
# ('2022-09-11', 'Producto 2', 'País 2', 7098)
# ('2022-09-20', 'Producto 1', 'País 2', 6651)
# ('2022-03-27', 'Producto 1', 'País 3', 8565)
# ('2022-08-04', 'Producto 3', 'País 3', 5456)
# ('2022-07-10', 'Producto 1', 'País 3', 8290)
# ('2022-02-28', 'Producto 2', 'País 1', 5204)
# ('2022-02-26', 'Producto 2', 'País 2', 7926)
# ('2022-04-22', 'Producto 2', 'País 3', 8074)
# ('2022-10-10', 'Producto 3', 'País 1', 3674)
# ('2022-06-23', 'Producto 1', 'País 1', 7881)
# ('2022-10-01', 'Producto 3', 'País 2', 5344)
# ('2022-09-04', 'Producto 1', 'País 2', 9264)
# ('2022-03-21', 'Producto 2', 'País 2', 1569)
# ('2022-05-06', 'Producto 1', 'País 2', 8595)
# ('2022-12-07', 'Producto 3', 'País 1', 3206)
# ('2022-01-07', 'Producto 3', 'País 3', 4755)
# ('2022-06-21', 'Producto 3', 'País 3', 9760)
# ('2022-09-18', 'Producto 1', 'País 2', 7054)
# ('2022-08-15', 'Producto 1', 'País 1', 636)
# ('2022-02-19', 'Producto 1', 'País 3', 191)
# ('2022-08-05', 'Producto 2', 'País 2', 3497)
# ('2022-02-24', 'Producto 3', 'País 2', 7467)
# ('2022-11-10', 'Producto 2', 'País 3', 5475)
# ('2022-01-28', 'Producto 3', 'País 2', 1284)
# ('2022-05-21', 'Producto 3', 'País 2', 3508)
# ('2022-01-13', 'Producto 2', 'País 1', 4854)
# ('2022-04-22', 'Producto 2', 'País 2', 6913)
# ('2022-01-28', 'Producto 2', 'País 2', 4237)
# ('2022-02-27', 'Producto 3', 'País 3', 7677)
# ('2022-07-11', 'Producto 1', 'País 1', 7323)
# ('2022-08-20', 'Producto 2', 'País 3', 9311)
# ('2022-02-07', 'Producto 1', 'País 3', 9834)
# ('2022-06-19', 'Producto 1', 'País 1', 4445)
# ('2022-05-07', 'Producto 3', 'País 1', 8914)
# ('2022-01-11', 'Producto 3', 'País 3', 8414)
# ('2022-03-03', 'Producto 1', 'País 1', 4011)
# ('2022-05-16', 'Producto 3', 'País 1', 7561)
# ('2022-11-26', 'Producto 2', 'País 3', 2315)
# ('2022-05-05', 'Producto 3', 'País 1', 8614)
# ('2022-07-26', 'Producto 3', 'País 2', 1858)
# ('2022-11-28', 'Producto 2', 'País 1', 6894)
# ('2022-07-22', 'Producto 2', 'País 2', 5263)
# ('2022-09-12', 'Producto 3', 'País 2', 8657)
# ('2022-02-11', 'Producto 1', 'País 3', 2719)
# ('2022-09-15', 'Producto 2', 'País 2', 8188)
# ('2022-07-05', 'Producto 2', 'País 3', 4402)
# ('2022-04-25', 'Producto 1', 'País 1', 6747)
# ('2022-10-13', 'Producto 1', 'País 1', 4404)
# ('2022-07-06', 'Producto 1', 'País 1', 5778)
# ('2022-12-20', 'Producto 3', 'País 2', 9333)
# ('2022-04-16', 'Producto 1', 'País 3', 5746)
# ('2022-08-20', 'Producto 3', 'País 2', 3622)
# ('2022-02-12', 'Producto 3', 'País 1', 5277)
# ('2022-11-21', 'Producto 2', 'País 2', 5810)
# ('2022-05-03', 'Producto 1', 'País 2', 3485)
# ('2022-11-07', 'Producto 2', 'País 2', 9016)
# ('2022-03-16', 'Producto 2', 'País 1', 351)
# ('2022-02-25', 'Producto 1', 'País 3', 3193)
# ('2022-05-20', 'Producto 2', 'País 1', 8249)
# ('2022-08-26', 'Producto 1', 'País 2', 3598)
# ('2022-08-19', 'Producto 1', 'País 1', 5354)
# ('2022-01-19', 'Producto 2', 'País 3', 2857)
# ('2022-03-03', 'Producto 2', 'País 2', 8403)
# ('2022-07-24', 'Producto 1', 'País 3', 9483)
# ('2022-08-25', 'Producto 2', 'País 3', 6013)
# ('2022-12-16', 'Producto 3', 'País 3', 741)
# ('2022-03-20', 'Producto 1', 'País 1', 7585)
# ('2022-09-20', 'Producto 2', 'País 1', 8238)
# ('2022-06-10', 'Producto 2', 'País 3', 2232)
# ('2022-12-22', 'Producto 1', 'País 1', 8303)
# ('2022-03-21', 'Producto 1', 'País 1', 2518)
# ('2022-05-05', 'Producto 3', 'País 1', 7666)
# ('2022-12-16', 'Producto 2', 'País 2', 9395)
# ('2022-11-11', 'Producto 2', 'País 2', 2760)
# ('2022-06-27', 'Producto 1', 'País 1', 8575)
# ('2022-08-25', 'Producto 3', 'País 3', 5524)
# ('2022-01-08', 'Producto 1', 'País 3', 6290)
# ('2022-06-11', 'Producto 1', 'País 2', 9644)
# ('2022-08-23', 'Producto 3', 'País 3', 8156)
# ('2022-08-12', 'Producto 3', 'País 3', 2180)
# ('2022-06-28', 'Producto 3', 'País 2', 6089)
# ('2022-08-13', 'Producto 3', 'País 1', 4891)
# ('2022-10-07', 'Producto 3', 'País 2', 6167)
# ('2022-08-09', 'Producto 3', 'País 3', 946)
# ('2022-04-13', 'Producto 1', 'País 2', 9057)
# ('2022-05-16', 'Producto 1', 'País 1', 1635)
# ('2022-01-09', 'Producto 3', 'País 3', 2563)
# ('2022-04-28', 'Producto 1', 'País 1', 1308)
# ('2022-07-02', 'Producto 3', 'País 3', 2565)
# ('2022-05-19', 'Producto 1', 'País 3', 2184)
# ('2022-07-27', 'Producto 1', 'País 1', 2029)
# ('2022-05-05', 'Producto 2', 'País 3', 9156)
# ('2022-10-12', 'Producto 1', 'País 1', 6393)
# ('2022-10-21', 'Producto 1', 'País 3', 1548)
# ('2022-03-23', 'Producto 3', 'País 1', 3445)
# ('2022-06-20', 'Producto 3', 'País 2', 7040)
# ('2022-03-09', 'Producto 1', 'País 2', 1357)
# ('2022-12-26', 'Producto 1', 'País 3', 1676)
# ('2022-01-03', 'Producto 3', 'País 3', 2488)
# ('2022-01-27', 'Producto 1', 'País 3', 6194)
# ('2022-11-23', 'Producto 3', 'País 2', 8856)
# ('2022-09-06', 'Producto 2', 'País 3', 8352)
# ('2022-03-23', 'Producto 2', 'País 3', 6194)
# ('2022-08-12', 'Producto 2', 'País 2', 6749)
# ('2022-02-12', 'Producto 2', 'País 2', 4171)
# ('2022-10-28', 'Producto 1', 'País 2', 220)
# ('2022-04-16', 'Producto 3', 'País 3', 465)
# ('2022-03-20', 'Producto 3', 'País 3', 3209)
# ('2022-11-11', 'Producto 1', 'País 3', 4209)
# ('2022-09-28', 'Producto 1', 'País 1', 9073)
# ('2022-09-10', 'Producto 3', 'País 2', 615)
# ('2022-09-07', 'Producto 2', 'País 3', 9275)
# ('2022-08-02', 'Producto 1', 'País 2', 1538)
# ('2022-03-10', 'Producto 2', 'País 2', 6384)
# ('2022-09-06', 'Producto 3', 'País 3', 9544)
# ('2022-04-15', 'Producto 3', 'País 1', 8535)
# ('2022-05-24', 'Producto 2', 'País 3', 9522)
# ('2022-10-20', 'Producto 2', 'País 1', 8204)
# ('2022-05-14', 'Producto 2', 'País 3', 5121)
# ('2022-03-20', 'Producto 1', 'País 2', 401)
# ('2022-12-01', 'Producto 1', 'País 1', 2614)
# ('2022-12-11', 'Producto 1', 'País 1', 4038)
# ('2022-03-19', 'Producto 3', 'País 3', 6766)
# ('2022-10-13', 'Producto 1', 'País 2', 5311)
# ('2022-05-03', 'Producto 3', 'País 3', 3966)
# ('2022-02-06', 'Producto 1', 'País 1', 1869)
# ('2022-10-25', 'Producto 2', 'País 1', 711)
# ('2022-08-19', 'Producto 1', 'País 3', 879)
# ('2022-05-16', 'Producto 2', 'País 3', 5377)
# ('2022-07-13', 'Producto 2', 'País 2', 5192)
# ('2022-06-12', 'Producto 2', 'País 1', 2173)
# ('2022-12-11', 'Producto 2', 'País 3', 733)
# ('2022-07-08', 'Producto 3', 'País 3', 8881)
# ('2022-09-08', 'Producto 3', 'País 2', 7651)
# ('2022-09-25', 'Producto 2', 'País 2', 3093)
# ('2022-12-22', 'Producto 2', 'País 3', 7198)
# ('2022-06-20', 'Producto 2', 'País 2', 4482)
# ('2022-06-01', 'Producto 3', 'País 1', 4360)
# ('2022-09-12', 'Producto 1', 'País 3', 7543)
# ('2022-08-17', 'Producto 1', 'País 3', 173)
# ('2022-09-10', 'Producto 3', 'País 3', 1368)
# ('2022-11-28', 'Producto 2', 'País 2', 3307)
# ('2022-05-07', 'Producto 1', 'País 3', 1448)
# ('2022-01-03', 'Producto 1', 'País 3', 2206)
# ('2022-09-23', 'Producto 2', 'País 1', 8523)
# ('2022-10-04', 'Producto 2', 'País 1', 2192)
# ('2022-09-01', 'Producto 2', 'País 1', 6908)
# ('2022-06-01', 'Producto 2', 'País 1', 7462)
# ('2022-10-22', 'Producto 3', 'País 2', 3295)
# ('2022-03-06', 'Producto 2', 'País 1', 1666)
# ('2022-10-22', 'Producto 1', 'País 3', 6839)
# ('2022-10-20', 'Producto 1', 'País 2', 3345)
# ('2022-09-01', 'Producto 1', 'País 3', 732)
# ('2022-09-09', 'Producto 3', 'País 1', 5718)
# ('2022-05-25', 'Producto 2', 'País 2', 3264)
# ('2022-09-11', 'Producto 1', 'País 1', 6971)
# ('2022-04-12', 'Producto 1', 'País 2', 6863)
# ('2022-03-24', 'Producto 1', 'País 1', 9602)
# ('2022-10-10', 'Producto 3', 'País 3', 2290)
# ('2022-01-23', 'Producto 2', 'País 2', 7431)
# ('2022-02-11', 'Producto 3', 'País 1', 4463)
# ('2022-04-05', 'Producto 1', 'País 1', 9744)
# ('2022-07-16', 'Producto 3', 'País 2', 5887)
# ('2022-07-11', 'Producto 2', 'País 3', 820)
# ('2022-10-27', 'Producto 3', 'País 3', 624)
# ('2022-02-20', 'Producto 2', 'País 2', 9935)
# ('2022-03-23', 'Producto 3', 'País 3', 5065)
# ('2022-01-04', 'Producto 2', 'País 1', 4893)
# ('2022-09-03', 'Producto 3', 'País 3', 4752)
# ('2022-10-22', 'Producto 2', 'País 1', 8042)
# ('2022-07-03', 'Producto 1', 'País 1', 5231)
# ('2022-07-26', 'Producto 3', 'País 2', 7434)
# ('2022-12-09', 'Producto 1', 'País 1', 905)
# ('2022-02-19', 'Producto 1', 'País 1', 1997)
# ('2022-03-26', 'Producto 3', 'País 3', 153)
# ('2022-04-24', 'Producto 3', 'País 1', 4079)
# ('2022-08-20', 'Producto 1', 'País 3', 3543)
# ('2022-08-04', 'Producto 1', 'País 3', 3204)
# ('2022-11-23', 'Producto 2', 'País 2', 5233)
# ('2022-04-14', 'Producto 1', 'País 3', 5109)
# ('2022-08-28', 'Producto 1', 'País 3', 443)
# ('2022-06-25', 'Producto 2', 'País 2', 2564)
# ('2022-11-08', 'Producto 3', 'País 1', 6709)
# ('2022-12-23', 'Producto 3', 'País 2', 1071)
# ('2022-10-18', 'Producto 1', 'País 3', 9815)
# ('2022-03-07', 'Producto 3', 'País 1', 672)
# ('2022-03-10', 'Producto 2', 'País 1', 9463)
# ('2022-10-23', 'Producto 3', 'País 3', 6961)
# ('2022-06-06', 'Producto 1', 'País 2', 4345)
# ('2022-07-27', 'Producto 3', 'País 1', 4861)
# ('2022-12-23', 'Producto 2', 'País 3', 6124)
# ('2022-06-05', 'Producto 1', 'País 2', 6599)
# ('2022-04-08', 'Producto 3', 'País 3', 1305)
# ('2022-02-05', 'Producto 2', 'País 3', 3812)
# ('2022-02-16', 'Producto 3', 'País 3', 6408)
# ('2022-12-21', 'Producto 2', 'País 1', 1930)
# ('2022-04-26', 'Producto 1', 'País 3', 7060)
# ('2022-10-08', 'Producto 3', 'País 1', 8538)
# ('2022-12-10', 'Producto 3', 'País 1', 2438)
# ('2022-04-08', 'Producto 3', 'País 1', 9501)
# ('2022-08-26', 'Producto 2', 'País 3', 9302)
# ('2022-04-21', 'Producto 1', 'País 3', 201)
# ('2022-08-20', 'Producto 2', 'País 3', 1305)
# ('2022-12-02', 'Producto 1', 'País 2', 8529)
# ('2022-10-16', 'Producto 3', 'País 2', 3968)
# ('2022-06-15', 'Producto 1', 'País 3', 4386)
# ('2022-01-26', 'Producto 2', 'País 1', 6186)
# ('2022-12-24', 'Producto 1', 'País 2', 4852)
# ('2022-11-05', 'Producto 1', 'País 2', 8515)
# ('2022-10-16', 'Producto 3', 'País 3', 7292)
# ('2022-12-15', 'Producto 1', 'País 2', 992)
# ('2022-03-15', 'Producto 3', 'País 2', 8353)
# ('2022-07-23', 'Producto 1', 'País 3', 3581)
# ('2022-06-12', 'Producto 1', 'País 1', 3968)
# ('2022-07-27', 'Producto 3', 'País 1', 3509)
# ('2022-06-09', 'Producto 2', 'País 1', 9191)
# ('2022-10-06', 'Producto 2', 'País 1', 6345)
# ('2022-09-28', 'Producto 1', 'País 3', 5152)
# ('2022-07-27', 'Producto 2', 'País 2', 9263)
# ('2022-01-18', 'Producto 3', 'País 3', 1915)
# ('2022-07-25', 'Producto 2', 'País 2', 2214)
# ('2022-07-20', 'Producto 1', 'País 1', 8226)
# ('2022-07-05', 'Producto 2', 'País 3', 6743)
# ('2022-07-27', 'Producto 3', 'País 1', 2219)
# ('2022-07-11', 'Producto 1', 'País 1', 9847)
# ('2022-06-13', 'Producto 2', 'País 3', 7670)
# ('2022-04-05', 'Producto 3', 'País 3', 8738)
# ('2022-10-08', 'Producto 2', 'País 3', 2915)
# ('2022-12-20', 'Producto 1', 'País 3', 8423)
# ('2022-09-19', 'Producto 3', 'País 1', 1661)
# ('2022-02-06', 'Producto 3', 'País 3', 948)
# ('2022-07-24', 'Producto 3', 'País 2', 6558)
# ('2022-12-22', 'Producto 2', 'País 3', 935)
# ('2022-07-06', 'Producto 2', 'País 3', 6667)
# ('2022-09-03', 'Producto 2', 'País 2', 4476)
# ('2022-07-21', 'Producto 2', 'País 1', 3564)
# ('2022-08-25', 'Producto 3', 'País 3', 405)
# ('2022-07-08', 'Producto 2', 'País 1', 729)
# ('2022-10-02', 'Producto 3', 'País 3', 9214)
# ('2022-07-16', 'Producto 2', 'País 3', 6606)
# ('2022-02-08', 'Producto 1', 'País 1', 2788)
# ('2022-10-13', 'Producto 3', 'País 3', 8721)
# ('2022-05-11', 'Producto 3', 'País 3', 2978)
# ('2022-01-15', 'Producto 1', 'País 2', 5228)
# ('2022-11-19', 'Producto 1', 'País 3', 7388)
# ('2022-01-17', 'Producto 1', 'País 3', 3143)
# ('2022-03-13', 'Producto 3', 'País 3', 2046)
# ('2022-04-05', 'Producto 3', 'País 1', 4045)
# ('2022-03-10', 'Producto 2', 'País 2', 4732)
# ('2022-02-14', 'Producto 3', 'País 2', 5041)
# ('2022-11-26', 'Producto 3', 'País 2', 6354)
# ('2022-11-05', 'Producto 2', 'País 1', 6223)
# ('2022-07-05', 'Producto 3', 'País 2', 1094)
# ('2022-06-25', 'Producto 1', 'País 3', 4870)
# ('2022-06-24', 'Producto 3', 'País 3', 3853)
# ('2022-09-01', 'Producto 1', 'País 3', 2047)
# ('2022-02-22', 'Producto 3', 'País 1', 3721)
# ('2022-03-19', 'Producto 3', 'País 2', 2909)
# ('2022-08-02', 'Producto 3', 'País 3', 8546)
# ('2022-03-01', 'Producto 1', 'País 1', 5950)
# ('2022-05-08', 'Producto 3', 'País 2', 6948)
# ('2022-02-08', 'Producto 3', 'País 2', 6950)
# ('2022-06-14', 'Producto 2', 'País 3', 6623)
# ('2022-04-16', 'Producto 1', 'País 2', 4256)
# ('2022-07-25', 'Producto 1', 'País 2', 1296)
# ('2022-05-15', 'Producto 1', 'País 1', 6379)
# ('2022-10-05', 'Producto 2', 'País 1', 7006)
# ('2022-01-01', 'Producto 3', 'País 1', 9031)
# ('2022-02-27', 'Producto 3', 'País 1', 322)
# ('2022-01-26', 'Producto 1', 'País 1', 683)
# ('2022-03-27', 'Producto 2', 'País 2', 4874)
# ('2022-10-27', 'Producto 3', 'País 2', 9829)
# ('2022-02-11', 'Producto 1', 'País 1', 2504)
# ('2022-08-22', 'Producto 1', 'País 3', 1535)
# ('2022-04-09', 'Producto 3', 'País 3', 7214)
# ('2022-04-15', 'Producto 3', 'País 2', 5546)
# ('2022-01-01', 'Producto 2', 'País 2', 5616)
# ('2022-08-28', 'Producto 1', 'País 3', 4003)
# ('2022-07-21', 'Producto 3', 'País 3', 6640)
# ('2022-04-17', 'Producto 3', 'País 2', 4406)
# ('2022-03-26', 'Producto 1', 'País 3', 4216)
# ('2022-04-08', 'Producto 1', 'País 2', 956)
# ('2022-01-19', 'Producto 3', 'País 2', 1713)
# ('2022-05-23', 'Producto 3', 'País 3', 9928)
# ('2022-08-03', 'Producto 3', 'País 3', 7138)
# ('2022-03-03', 'Producto 2', 'País 1', 5014)
# ('2022-10-22', 'Producto 3', 'País 3', 1075)
# ('2022-05-09', 'Producto 1', 'País 2', 8160)
# ('2022-06-13', 'Producto 2', 'País 1', 3639)
# ('2022-01-13', 'Producto 2', 'País 3', 6527)
# ('2022-06-03', 'Producto 1', 'País 2', 3181)
# ('2022-12-08', 'Producto 3', 'País 1', 3451)
# ('2022-06-27', 'Producto 1', 'País 1', 166)
# ('2022-05-19', 'Producto 2', 'País 1', 2964)
# ('2022-01-19', 'Producto 2', 'País 2', 1756)
# ('2022-04-21', 'Producto 1', 'País 2', 1988)
# ('2022-09-21', 'Producto 2', 'País 3', 6085)
# ('2022-08-24', 'Producto 3', 'País 1', 5015)
# ('2022-07-06', 'Producto 3', 'País 3', 7161)
# ('2022-03-18', 'Producto 2', 'País 1', 6363)
# ('2022-06-22', 'Producto 3', 'País 3', 9381)
# ('2022-10-04', 'Producto 3', 'País 3', 1179)
# ('2022-11-05', 'Producto 1', 'País 1', 5994)
# ('2022-12-01', 'Producto 3', 'País 2', 7669)
# ('2022-08-18', 'Producto 2', 'País 3', 4126)
# ('2022-04-03', 'Producto 2', 'País 3', 6789)
# ('2022-06-14', 'Producto 1', 'País 1', 4276)
# ('2022-06-12', 'Producto 3', 'País 3', 298)
# ('2022-10-14', 'Producto 2', 'País 1', 8488)
# ('2022-04-21', 'Producto 2', 'País 2', 8686)
# ('2022-12-22', 'Producto 2', 'País 3', 2455)
# ('2022-09-24', 'Producto 2', 'País 3', 1430)
# ('2022-04-11', 'Producto 1', 'País 3', 2046)
# ('2022-07-02', 'Producto 3', 'País 2', 6217)
# ('2022-05-18', 'Producto 3', 'País 1', 7099)
# ('2022-10-09', 'Producto 3', 'País 2', 2549)
# ('2022-01-16', 'Producto 3', 'País 1', 6105)
# ('2022-08-04', 'Producto 2', 'País 1', 253)
# ('2022-07-12', 'Producto 1', 'País 1', 6613)
# ('2022-06-06', 'Producto 3', 'País 2', 2837)
# ('2022-01-14', 'Producto 1', 'País 2', 1561)
# ('2022-05-17', 'Producto 2', 'País 3', 9771)
# ('2022-02-16', 'Producto 2', 'País 3', 818)
# ('2022-12-28', 'Producto 1', 'País 1', 5963)
# ('2022-08-01', 'Producto 2', 'País 1', 3174)
# ('2022-08-06', 'Producto 1', 'País 3', 4609)
# ('2022-04-11', 'Producto 2', 'País 1', 2500)
# ('2022-01-21', 'Producto 3', 'País 1', 3394)
# ('2022-12-16', 'Producto 3', 'País 2', 4257)
# ('2022-10-06', 'Producto 3', 'País 3', 6325)
# ('2022-02-06', 'Producto 1', 'País 3', 1695)
# ('2022-12-13', 'Producto 1', 'País 2', 9548)
# ('2022-05-27', 'Producto 1', 'País 1', 4630)
# ('2022-12-17', 'Producto 1', 'País 3', 4106)
# ('2022-09-19', 'Producto 3', 'País 3', 7441)
# ('2022-05-14', 'Producto 2', 'País 2', 9605)
# ('2022-05-16', 'Producto 3', 'País 3', 3775)
# ('2022-05-19', 'Producto 3', 'País 2', 1788)
# ('2022-09-20', 'Producto 2', 'País 2', 7473)
# ('2022-11-02', 'Producto 3', 'País 1', 5361)
# ('2022-05-28', 'Producto 2', 'País 1', 9812)
# ('2022-09-04', 'Producto 3', 'País 2', 2965)
# ('2022-07-26', 'Producto 2', 'País 2', 4215)
# ('2022-01-13', 'Producto 1', 'País 1', 2123)
# ('2022-11-10', 'Producto 3', 'País 3', 2646)
# ('2022-08-03', 'Producto 1', 'País 3', 5186)
# ('2022-03-01', 'Producto 1', 'País 3', 9919)
# ('2022-12-09', 'Producto 1', 'País 1', 2227)
# ('2022-05-13', 'Producto 3', 'País 2', 5606)
# ('2022-05-01', 'Producto 3', 'País 3', 7772)
# ('2022-02-09', 'Producto 2', 'País 3', 1340)
# ('2022-04-02', 'Producto 1', 'País 3', 3252)
# ('2022-01-06', 'Producto 1', 'País 3', 6895)
# ('2022-02-27', 'Producto 3', 'País 2', 3584)
# ('2022-11-25', 'Producto 3', 'País 3', 2362)
# ('2022-12-16', 'Producto 1', 'País 2', 4267)
# ('2022-06-20', 'Producto 3', 'País 2', 7788)
# ('2022-04-08', 'Producto 3', 'País 3', 6177)
# ('2022-06-09', 'Producto 2', 'País 2', 6761)
# ('2022-12-22', 'Producto 1', 'País 1', 5310)
# ('2022-11-18', 'Producto 2', 'País 2', 3423)
# ('2022-07-16', 'Producto 2', 'País 1', 2058)
# ('2022-12-24', 'Producto 1', 'País 1', 5223)
# ('2022-03-27', 'Producto 3', 'País 1', 1717)
# ('2022-10-10', 'Producto 2', 'País 3', 1867)
# ('2022-06-24', 'Producto 2', 'País 3', 6345)
# ('2022-08-24', 'Producto 1', 'País 3', 6457)
# ('2022-07-16', 'Producto 3', 'País 3', 9194)
# ('2022-09-10', 'Producto 1', 'País 2', 6378)
# ('2022-08-16', 'Producto 1', 'País 2', 2963)
# ('2022-08-07', 'Producto 3', 'País 3', 5542)
# ('2022-09-24', 'Producto 2', 'País 3', 7794)
# ('2022-04-24', 'Producto 1', 'País 3', 6037)
# ('2022-08-27', 'Producto 2', 'País 1', 9090)
# ('2022-12-06', 'Producto 2', 'País 3', 7375)
# ('2022-04-06', 'Producto 3', 'País 2', 7851)
# ('2022-05-17', 'Producto 3', 'País 1', 9292)
# ('2022-01-17', 'Producto 3', 'País 3', 8844)
# ('2022-01-18', 'Producto 1', 'País 3', 672)
# ('2022-03-28', 'Producto 3', 'País 3', 8734)
# ('2022-12-25', 'Producto 3', 'País 2', 7837)
# ('2022-06-15', 'Producto 1', 'País 2', 4072)
# ('2022-04-28', 'Producto 2', 'País 1', 3059)
# ('2022-02-03', 'Producto 2', 'País 1', 5615)
# ('2022-04-15', 'Producto 3', 'País 2', 3484)
# ('2022-07-03', 'Producto 2', 'País 1', 7565)
# ('2022-02-18', 'Producto 2', 'País 1', 4514)
# ('2022-06-20', 'Producto 2', 'País 3', 8593)
# ('2022-07-08', 'Producto 1', 'País 1', 8873)
# ('2022-08-09', 'Producto 2', 'País 1', 5081)
# ('2022-11-06', 'Producto 2', 'País 2', 1338)
# ('2022-09-15', 'Producto 1', 'País 2', 384)
# ('2022-12-04', 'Producto 2', 'País 1', 6775)
# ('2022-06-26', 'Producto 3', 'País 3', 1048)
# ('2022-01-25', 'Producto 3', 'País 1', 4822)
# ('2022-06-10', 'Producto 2', 'País 3', 3502)
# ('2022-09-08', 'Producto 3', 'País 3', 3335)
# ('2022-08-14', 'Producto 2', 'País 1', 7040)
# ('2022-11-12', 'Producto 1', 'País 3', 1754)
# ('2022-08-25', 'Producto 2', 'País 2', 7259)
# ('2022-10-22', 'Producto 2', 'País 2', 9824)
# ('2022-12-17', 'Producto 3', 'País 1', 4749)
# ('2022-10-15', 'Producto 3', 'País 2', 9728)
# ('2022-10-01', 'Producto 2', 'País 2', 1492)
# ('2022-06-06', 'Producto 3', 'País 1', 1691)
# ('2022-01-28', 'Producto 2', 'País 1', 4586)
# ('2022-05-15', 'Producto 2', 'País 3', 4126)
# ('2022-05-06', 'Producto 3', 'País 2', 5503)
# ('2022-01-08', 'Producto 1', 'País 1', 874)
# ('2022-11-10', 'Producto 1', 'País 1', 3723)
# ('2022-03-05', 'Producto 3', 'País 1', 8067)
# ('2022-07-24', 'Producto 2', 'País 1', 3286)
# ('2022-04-05', 'Producto 1', 'País 2', 2352)
# ('2022-09-22', 'Producto 2', 'País 2', 9250)
# ('2022-12-28', 'Producto 3', 'País 2', 7389)
# ('2022-04-10', 'Producto 1', 'País 1', 3988)
# ('2022-06-17', 'Producto 3', 'País 1', 4916)
# ('2022-10-16', 'Producto 3', 'País 1', 3561)
# ('2022-11-11', 'Producto 3', 'País 3', 8692)
# ('2022-10-06', 'Producto 2', 'País 3', 2904)
# ('2022-10-02', 'Producto 3', 'País 3', 5438)
# ('2022-02-08', 'Producto 3', 'País 2', 6954)
# ('2022-07-04', 'Producto 1', 'País 3', 4995)
# ('2022-05-20', 'Producto 3', 'País 3', 9263)
# ('2022-07-02', 'Producto 1', 'País 2', 290)
# ('2022-07-18', 'Producto 3', 'País 3', 9276)
# ('2022-12-01', 'Producto 2', 'País 2', 4245)
# ('2022-02-26', 'Producto 1', 'País 3', 9902)
# ('2022-10-07', 'Producto 2', 'País 2', 3672)
# ('2022-06-09', 'Producto 3', 'País 2', 3256)
# ('2022-06-10', 'Producto 3', 'País 3', 2780)
# ('2022-11-25', 'Producto 2', 'País 2', 7139)
# ('2022-04-04', 'Producto 3', 'País 3', 2388)
# ('2022-05-04', 'Producto 1', 'País 1', 5469)
# ('2022-09-08', 'Producto 2', 'País 1', 4604)
# ('2022-06-28', 'Producto 2', 'País 1', 2554)
# ('2022-11-16', 'Producto 2', 'País 3', 5629)
# ('2022-04-06', 'Producto 3', 'País 1', 5480)
# ('2022-09-25', 'Producto 3', 'País 3', 1924)
# ('2022-01-22', 'Producto 3', 'País 1', 1004)
# ('2022-10-19', 'Producto 1', 'País 3', 4380)
# ('2022-09-10', 'Producto 1', 'País 1', 2024)
# ('2022-03-26', 'Producto 1', 'País 1', 976)
# ('2022-10-27', 'Producto 1', 'País 1', 3361)
# ('2022-03-08', 'Producto 2', 'País 1', 7471)
# ('2022-12-04', 'Producto 2', 'País 2', 3106)
# ('2022-04-01', 'Producto 2', 'País 3', 5125)
# ('2022-08-19', 'Producto 2', 'País 1', 6645)
# ('2022-10-22', 'Producto 2', 'País 1', 1965)
# ('2022-10-04', 'Producto 2', 'País 3', 4383)
# ('2022-04-11', 'Producto 3', 'País 1', 3563)
# ('2022-03-22', 'Producto 1', 'País 1', 9468)
# ('2022-04-14', 'Producto 2', 'País 3', 6039)
# ('2022-06-05', 'Producto 2', 'País 1', 8276)
# ('2022-03-27', 'Producto 2', 'País 3', 829)
# ('2022-11-12', 'Producto 1', 'País 3', 2287)
# ('2022-06-25', 'Producto 1', 'País 3', 9633)
# ...
# ('2022-02-23', 'Producto 2', 'País 3', 9060)
# ('2022-07-13', 'Producto 2', 'País 3', 133)
# ('2022-07-26', 'Producto 2', 'País 1', 4546)
# ('2022-07-10', 'Producto 1', 'País 3', 6539)
# ('2022-05-06', 'Producto 3', 'País 1', 1985)
# ('2022-02-27', 'Producto 2', 'País 3', 3995)
# ('2022-07-20', 'Producto 2', 'País 2', 976)
# ('2022-07-17', 'Producto 2', 'País 2', 7104)
# ('2022-07-11', 'Producto 3', 'País 3', 3860)
# ('2022-05-12', 'Producto 1', 'País 1', 5309)
# ('2022-09-26', 'Producto 2', 'País 2', 737)
# ('2022-09-11', 'Producto 3', 'País 1', 2183)
# ('2022-06-08', 'Producto 2', 'País 3', 4736)
# ('2022-07-08', 'Producto 2', 'País 1', 7086)
# ('2022-04-07', 'Producto 3', 'País 3', 9254)
# ('2022-01-18', 'Producto 1', 'País 2', 337)
# ('2022-03-24', 'Producto 2', 'País 3', 3226)
# ('2022-09-25', 'Producto 3', 'País 2', 3312)
# ('2022-02-08', 'Producto 2', 'País 1', 6465)
# ('2022-01-01', 'Producto 3', 'País 2', 3317)
# ('2022-05-03', 'Producto 3', 'País 3', 3685)
# ('2022-11-11', 'Producto 3', 'País 2', 1866)
# ('2022-02-28', 'Producto 3', 'País 3', 5583)
# ('2022-05-19', 'Producto 3', 'País 2', 532)
# ('2022-07-17', 'Producto 3', 'País 2', 5770)
# ('2022-12-03', 'Producto 2', 'País 1', 7337)
# ('2022-04-20', 'Producto 1', 'País 3', 3818)
# ('2022-08-10', 'Producto 1', 'País 1', 7282)
# ('2022-07-09', 'Producto 3', 'País 2', 9415)
# ('2022-06-26', 'Producto 3', 'País 2', 8427)
# ('2022-01-18', 'Producto 1', 'País 1', 3658)
# ('2022-03-01', 'Producto 2', 'País 2', 8890)
# ('2022-05-20', 'Producto 2', 'País 2', 4686)
# ('2022-07-24', 'Producto 1', 'País 2', 3669)
# ('2022-10-10', 'Producto 2', 'País 2', 1025)
# ('2022-03-24', 'Producto 2', 'País 1', 969)
# ('2022-02-26', 'Producto 1', 'País 3', 2163)
# ('2022-03-13', 'Producto 3', 'País 1', 5030)
# ('2022-11-22', 'Producto 1', 'País 1', 3890)
# ('2022-02-20', 'Producto 3', 'País 2', 8427)
# ('2022-12-10', 'Producto 1', 'País 3', 7473)
# ('2022-11-01', 'Producto 2', 'País 2', 8713)
# ('2022-09-28', 'Producto 2', 'País 3', 4447)
# ('2022-07-12', 'Producto 2', 'País 2', 544)
# ('2022-12-04', 'Producto 2', 'País 1', 9968)
# ('2022-09-15', 'Producto 3', 'País 3', 2126)
# ('2022-11-19', 'Producto 2', 'País 2', 9786)
# ('2022-05-17', 'Producto 3', 'País 1', 4028)
# ('2022-11-05', 'Producto 1', 'País 1', 2445)
# ('2022-08-24', 'Producto 3', 'País 3', 3835)
# ('2022-11-24', 'Producto 2', 'País 3', 8855)
# ('2022-01-13', 'Producto 3', 'País 2', 759)
# ('2022-02-18', 'Producto 1', 'País 3', 7884)
# ('2022-10-01', 'Producto 1', 'País 1', 4694)
# ('2022-06-22', 'Producto 1', 'País 1', 6447)
# ('2022-03-25', 'Producto 3', 'País 1', 2769)
# ('2022-12-14', 'Producto 2', 'País 1', 572)
# ('2022-10-09', 'Producto 3', 'País 2', 2287)
# ('2022-11-15', 'Producto 3', 'País 3', 5948)
# ('2022-06-22', 'Producto 1', 'País 2', 3792)
# ('2022-02-17', 'Producto 3', 'País 1', 3934)
# ('2022-12-05', 'Producto 3', 'País 1', 941)
# ('2022-05-10', 'Producto 2', 'País 3', 2895)
# ('2022-02-12', 'Producto 1', 'País 2', 3913)
# ('2022-05-07', 'Producto 3', 'País 1', 8206)
# ('2022-04-03', 'Producto 3', 'País 1', 6587)
# ('2022-01-13', 'Producto 3', 'País 2', 696)
# ('2022-09-17', 'Producto 2', 'País 3', 9499)
# ('2022-08-08', 'Producto 2', 'País 2', 7024)
# ('2022-02-28', 'Producto 3', 'País 1', 4410)
# ('2022-06-17', 'Producto 1', 'País 2', 6026)
# ('2022-03-24', 'Producto 1', 'País 2', 8575)
# ('2022-01-14', 'Producto 3', 'País 3', 3626)
# ('2022-06-22', 'Producto 1', 'País 1', 8520)
# ('2022-04-04', 'Producto 1', 'País 1', 7735)
# ('2022-10-14', 'Producto 3', 'País 1', 7202)
# ('2022-03-20', 'Producto 3', 'País 3', 8458)
# ('2022-05-16', 'Producto 2', 'País 1', 5643)
# ('2022-06-11', 'Producto 3', 'País 1', 8844)
# ('2022-06-07', 'Producto 2', 'País 2', 786)
# ('2022-08-24', 'Producto 1', 'País 3', 7222)
# ('2022-08-16', 'Producto 1', 'País 2', 3436)
# ('2022-08-26', 'Producto 1', 'País 1', 8293)
# ('2022-08-14', 'Producto 1', 'País 3', 7332)
# ('2022-07-09', 'Producto 3', 'País 3', 4418)
# ('2022-07-18', 'Producto 3', 'País 2', 2045)
# ('2022-07-16', 'Producto 1', 'País 2', 6187)
# ('2022-01-12', 'Producto 2', 'País 1', 8438)
# ('2022-07-15', 'Producto 2', 'País 3', 9771)
# ('2022-10-04', 'Producto 1', 'País 1', 5051)
# ('2022-04-05', 'Producto 2', 'País 1', 5117)
# ('2022-04-04', 'Producto 1', 'País 3', 9717)
# ('2022-04-07', 'Producto 2', 'País 3', 9471)
# ('2022-07-09', 'Producto 2', 'País 1', 3654)
# ('2022-06-11', 'Producto 1', 'País 3', 9236)
# ('2022-02-15', 'Producto 2', 'País 3', 6241)
# ('2022-07-08', 'Producto 2', 'País 2', 4804)
# ('2022-05-07', 'Producto 2', 'País 1', 1835)
# ('2022-11-05', 'Producto 1', 'País 3', 8061)
# ('2022-01-05', 'Producto 3', 'País 1', 7116)
# ('2022-07-26', 'Producto 3', 'País 2', 8286)
# ('2022-02-03', 'Producto 2', 'País 2', 2892)
# ('2022-06-19', 'Producto 3', 'País 3', 8203)
# ('2022-05-26', 'Producto 2', 'País 2', 7249)
# ('2022-09-11', 'Producto 2', 'País 3', 4332)
# ('2022-07-26', 'Producto 2', 'País 2', 4937)
# ('2022-08-21', 'Producto 3', 'País 1', 2177)
# ('2022-09-10', 'Producto 1', 'País 1', 4598)
# ('2022-04-28', 'Producto 3', 'País 1', 4153)
# ('2022-10-12', 'Producto 1', 'País 3', 5234)
# ('2022-06-19', 'Producto 1', 'País 1', 9402)
# ('2022-01-21', 'Producto 3', 'País 3', 7849)
# ('2022-07-12', 'Producto 3', 'País 2', 4491)
# ('2022-01-09', 'Producto 1', 'País 1', 5376)
# ('2022-01-09', 'Producto 2', 'País 2', 4146)
# ('2022-11-27', 'Producto 3', 'País 1', 2607)
# ('2022-06-09', 'Producto 3', 'País 1', 8104)
# ('2022-11-24', 'Producto 2', 'País 1', 7370)
# ('2022-08-02', 'Producto 2', 'País 3', 6891)
# ('2022-02-15', 'Producto 2', 'País 3', 101)
# ('2022-08-19', 'Producto 2', 'País 1', 2750)
# ('2022-11-16', 'Producto 1', 'País 3', 3987)
# ('2022-09-09', 'Producto 1', 'País 2', 4135)
# ('2022-03-07', 'Producto 1', 'País 2', 4842)
# ('2022-05-13', 'Producto 1', 'País 1', 9669)
# ('2022-10-04', 'Producto 3', 'País 1', 7347)
# ('2022-10-12', 'Producto 2', 'País 2', 4864)
# ('2022-07-22', 'Producto 3', 'País 2', 5361)
# ('2022-05-14', 'Producto 1', 'País 3', 6093)
# ('2022-01-10', 'Producto 3', 'País 2', 2675)
# ('2022-03-04', 'Producto 3', 'País 1', 763)
# ('2022-10-28', 'Producto 2', 'País 1', 8605)
# ('2022-01-10', 'Producto 2', 'País 1', 998)
# ('2022-11-15', 'Producto 1', 'País 1', 519)
# ('2022-03-01', 'Producto 1', 'País 2', 8796)
# ('2022-02-14', 'Producto 1', 'País 1', 3131)
# ('2022-07-07', 'Producto 3', 'País 2', 6032)
# ('2022-03-28', 'Producto 2', 'País 3', 5254)
# ('2022-10-11', 'Producto 1', 'País 2', 9328)
# ('2022-01-12', 'Producto 3', 'País 3', 2669)
# ('2022-02-14', 'Producto 3', 'País 2', 5983)
# ('2022-03-19', 'Producto 3', 'País 2', 4719)
# ('2022-04-01', 'Producto 2', 'País 2', 3993)
# ('2022-04-07', 'Producto 3', 'País 3', 2274)
# ('2022-02-15', 'Producto 2', 'País 1', 103)
# ('2022-12-25', 'Producto 1', 'País 3', 4479)
# ('2022-11-19', 'Producto 2', 'País 1', 5653)
# ('2022-01-18', 'Producto 2', 'País 3', 6970)
# ('2022-08-12', 'Producto 2', 'País 1', 5179)
# ('2022-10-13', 'Producto 3', 'País 1', 1543)
# ('2022-08-13', 'Producto 3', 'País 1', 8559)
# ('2022-03-24', 'Producto 1', 'País 3', 1748)
# ('2022-07-24', 'Producto 3', 'País 2', 1815)
# ('2022-07-03', 'Producto 3', 'País 3', 7350)
# ('2022-09-15', 'Producto 2', 'País 3', 1926)
# ('2022-05-05', 'Producto 2', 'País 1', 5722)
# ('2022-03-12', 'Producto 3', 'País 3', 5241)
# ('2022-01-23', 'Producto 2', 'País 2', 1021)
# ('2022-10-17', 'Producto 3', 'País 3', 3755)
# ('2022-09-22', 'Producto 1', 'País 3', 9510)
# ('2022-08-25', 'Producto 2', 'País 3', 4084)
# ('2022-01-08', 'Producto 3', 'País 2', 4573)
# ('2022-09-12', 'Producto 2', 'País 2', 4206)
# ('2022-09-08', 'Producto 1', 'País 2', 5690)
# ('2022-03-08', 'Producto 1', 'País 3', 2072)
# ('2022-04-20', 'Producto 3', 'País 3', 770)
# ('2022-08-17', 'Producto 2', 'País 1', 702)
# ('2022-05-02', 'Producto 1', 'País 1', 1711)
# ('2022-08-12', 'Producto 1', 'País 1', 5333)
# ('2022-06-24', 'Producto 3', 'País 3', 5019)
# ('2022-11-22', 'Producto 2', 'País 2', 4866)
# ('2022-04-02', 'Producto 2', 'País 3', 844)
# ('2022-08-07', 'Producto 1', 'País 1', 8988)
# ('2022-09-20', 'Producto 3', 'País 1', 267)
# ('2022-11-14', 'Producto 3', 'País 1', 3784)
# ('2022-07-27', 'Producto 2', 'País 1', 2180)
# ('2022-04-09', 'Producto 3', 'País 2', 1168)
# ('2022-05-19', 'Producto 1', 'País 2', 2829)
# ('2022-11-20', 'Producto 1', 'País 3', 5395)
# ('2022-09-15', 'Producto 2', 'País 1', 160)
# ('2022-05-15', 'Producto 3', 'País 3', 228)
# ('2022-08-16', 'Producto 2', 'País 1', 8757)
# ('2022-07-07', 'Producto 2', 'País 3', 8233)
# ('2022-08-11', 'Producto 3', 'País 3', 1054)
# ('2022-08-23', 'Producto 2', 'País 1', 331)
# ('2022-12-05', 'Producto 1', 'País 1', 8426)
# ('2022-05-01', 'Producto 2', 'País 3', 5486)
# ('2022-06-14', 'Producto 3', 'País 3', 8740)
# ('2022-10-25', 'Producto 2', 'País 1', 1364)
# ('2022-11-03', 'Producto 2', 'País 3', 8377)
# ('2022-10-22', 'Producto 2', 'País 2', 5772)
# ('2022-02-26', 'Producto 1', 'País 1', 3688)
# ('2022-03-23', 'Producto 2', 'País 3', 9025)
# ('2022-01-09', 'Producto 1', 'País 1', 8198)
# ('2022-04-26', 'Producto 2', 'País 3', 2708)
# ('2022-05-08', 'Producto 2', 'País 1', 4259)
# ('2022-08-20', 'Producto 1', 'País 1', 8003)
# ('2022-05-06', 'Producto 2', 'País 1', 7509)
# ('2022-06-10', 'Producto 3', 'País 2', 3290)
# ('2022-02-24', 'Producto 2', 'País 1', 9456)
# ('2022-12-07', 'Producto 1', 'País 2', 1977)
# ('2022-08-25', 'Producto 2', 'País 1', 1384)
# ('2022-09-23', 'Producto 2', 'País 1', 8100)
# ('2022-03-06', 'Producto 1', 'País 1', 8365)
# ('2022-09-07', 'Producto 2', 'País 3', 2652)
# ('2022-10-03', 'Producto 2', 'País 3', 6704)
# ('2022-09-11', 'Producto 3', 'País 3', 5465)
# ('2022-05-25', 'Producto 2', 'País 1', 6648)
# ('2022-03-26', 'Producto 1', 'País 1', 6229)
# ('2022-05-19', 'Producto 2', 'País 1', 5785)
# ('2022-11-13', 'Producto 2', 'País 2', 6931)
# ('2022-04-10', 'Producto 2', 'País 1', 9500)
# ('2022-10-10', 'Producto 3', 'País 3', 441)
# ('2022-02-21', 'Producto 3', 'País 1', 5494)
# ('2022-11-05', 'Producto 1', 'País 2', 4787)
# ('2022-04-24', 'Producto 2', 'País 2', 7707)
# ('2022-08-17', 'Producto 3', 'País 3', 4575)
# ('2022-06-20', 'Producto 2', 'País 3', 2115)
# ('2022-01-09', 'Producto 1', 'País 1', 9493)
# ('2022-01-21', 'Producto 1', 'País 2', 8584)
# ('2022-10-16', 'Producto 3', 'País 2', 1471)
# ('2022-06-08', 'Producto 2', 'País 1', 4955)
# ('2022-07-15', 'Producto 3', 'País 2', 4191)
# ('2022-06-27', 'Producto 1', 'País 1', 9704)
# ('2022-11-16', 'Producto 2', 'País 2', 2116)
# ('2022-09-28', 'Producto 2', 'País 1', 125)
# ('2022-10-12', 'Producto 2', 'País 1', 1900)
# ('2022-04-23', 'Producto 2', 'País 1', 1950)
# ('2022-11-25', 'Producto 2', 'País 1', 2835)
# ('2022-06-08', 'Producto 1', 'País 3', 3154)
# ('2022-01-28', 'Producto 2', 'País 3', 4956)
# ('2022-11-06', 'Producto 1', 'País 1', 1036)
# ('2022-08-03', 'Producto 2', 'País 3', 1915)
# ('2022-05-11', 'Producto 3', 'País 3', 741)
# ('2022-06-20', 'Producto 3', 'País 3', 5733)
# ('2022-01-21', 'Producto 1', 'País 3', 1560)
# ('2022-02-11', 'Producto 1', 'País 1', 194)
# ('2022-12-09', 'Producto 2', 'País 3', 4740)
# ('2022-09-27', 'Producto 3', 'País 2', 9391)
# ('2022-09-23', 'Producto 3', 'País 2', 918)
# ('2022-11-07', 'Producto 1', 'País 2', 5215)
# ('2022-05-02', 'Producto 3', 'País 3', 3824)
# ('2022-02-15', 'Producto 1', 'País 3', 7889)
# ('2022-10-19', 'Producto 2', 'País 2', 9235)
# ('2022-04-25', 'Producto 1', 'País 1', 5196)
# ('2022-04-08', 'Producto 3', 'País 3', 4731)
# ('2022-08-22', 'Producto 1', 'País 3', 8388)
# ('2022-02-25', 'Producto 1', 'País 1', 9606)
# ('2022-10-25', 'Producto 2', 'País 3', 8276)
# ('2022-06-15', 'Producto 3', 'País 3', 5418)
# ('2022-09-17', 'Producto 2', 'País 2', 7045)
# ('2022-07-10', 'Producto 1', 'País 1', 2117)
# ('2022-03-24', 'Producto 1', 'País 2', 1138)
# ('2022-10-06', 'Producto 1', 'País 2', 3296)
# ('2022-12-10', 'Producto 2', 'País 1', 7092)
# ('2022-01-26', 'Producto 1', 'País 1', 2687)
# ('2022-01-10', 'Producto 3', 'País 3', 4448)
# ('2022-12-13', 'Producto 1', 'País 3', 6810)
# ('2022-04-23', 'Producto 2', 'País 2', 6261)
# ('2022-06-17', 'Producto 3', 'País 3', 3607)
# ('2022-12-12', 'Producto 2', 'País 2', 7898)
# ('2022-08-14', 'Producto 1', 'País 3', 3158)
# ('2022-10-16', 'Producto 2', 'País 3', 3939)
# ('2022-10-15', 'Producto 1', 'País 3', 5408)
# ('2022-07-14', 'Producto 2', 'País 1', 6392)
# ('2022-02-13', 'Producto 3', 'País 2', 9057)
# ('2022-12-19', 'Producto 3', 'País 1', 4051)
# ('2022-04-05', 'Producto 2', 'País 2', 3257)
# ('2022-04-28', 'Producto 2', 'País 2', 189)
# ('2022-12-23', 'Producto 1', 'País 2', 4074)
# ('2022-07-11', 'Producto 3', 'País 3', 5405)
# ('2022-04-02', 'Producto 1', 'País 2', 4289)
# ('2022-12-19', 'Producto 3', 'País 2', 9054)
# ('2022-10-04', 'Producto 3', 'País 3', 1299)
# ('2022-04-02', 'Producto 1', 'País 3', 6123)
# ('2022-09-19', 'Producto 1', 'País 3', 7802)
# ('2022-12-21', 'Producto 1', 'País 1', 1033)
# ('2022-11-07', 'Producto 3', 'País 2', 4246)
# ('2022-07-18', 'Producto 3', 'País 3', 5188)
# ('2022-02-18', 'Producto 1', 'País 2', 1605)
# ('2022-04-04', 'Producto 3', 'País 2', 1114)
# ('2022-11-10', 'Producto 1', 'País 3', 6573)
# ('2022-08-04', 'Producto 2', 'País 1', 3124)
# ('2022-09-17', 'Producto 1', 'País 3', 1364)
# ('2022-10-10', 'Producto 2', 'País 2', 1351)
# ('2022-01-10', 'Producto 1', 'País 3', 2374)
# ('2022-07-03', 'Producto 3', 'País 2', 1546)
# ('2022-05-06', 'Producto 3', 'País 1', 7215)
# ('2022-03-15', 'Producto 1', 'País 1', 6012)
# ('2022-07-11', 'Producto 3', 'País 3', 4320)
# ('2022-12-05', 'Producto 3', 'País 2', 1961)
# ('2022-05-11', 'Producto 1', 'País 3', 1538)
# ('2022-07-09', 'Producto 3', 'País 2', 7130)
# ('2022-04-12', 'Producto 3', 'País 1', 8024)
# ('2022-08-07', 'Producto 2', 'País 1', 2637)
# ('2022-11-06', 'Producto 3', 'País 1', 4112)
# ('2022-03-18', 'Producto 3', 'País 3', 5279)
# ('2022-06-17', 'Producto 1', 'País 1', 7833)
# ('2022-08-24', 'Producto 1', 'País 3', 7696)
# ('2022-04-28', 'Producto 1', 'País 1', 9431)
# ('2022-10-09', 'Producto 1', 'País 1', 4027)
# ('2022-05-20', 'Producto 2', 'País 2', 3550)
# ('2022-07-09', 'Producto 1', 'País 3', 8519)
# ('2022-01-09', 'Producto 1', 'País 1', 5305)
# ('2022-10-09', 'Producto 3', 'País 3', 3987)
# ('2022-04-13', 'Producto 3', 'País 3', 9821)
# ('2022-09-13', 'Producto 2', 'País 2', 683)
# ('2022-09-11', 'Producto 2', 'País 3', 1801)
# ('2022-03-06', 'Producto 3', 'País 2', 713)
# ('2022-07-08', 'Producto 2', 'País 1', 5175)
# ('2022-06-15', 'Producto 2', 'País 3', 6997)
# ('2022-04-13', 'Producto 1', 'País 3', 9723)
# ('2022-04-23', 'Producto 1', 'País 1', 1675)
# ('2022-02-09', 'Producto 2', 'País 2', 2851)
# ('2022-03-02', 'Producto 1', 'País 1', 1438)
# ('2022-06-23', 'Producto 3', 'País 2', 2759)
# ('2022-12-19', 'Producto 1', 'País 1', 9649)
# ('2022-07-25', 'Producto 3', 'País 1', 4708)
# ('2022-03-04', 'Producto 2', 'País 2', 9083)
# ('2022-11-18', 'Producto 1', 'País 1', 7157)
# ('2022-12-08', 'Producto 1', 'País 1', 4088)
# ('2022-08-21', 'Producto 2', 'País 1', 8129)
# ('2022-08-09', 'Producto 1', 'País 2', 4462)
# ('2022-01-10', 'Producto 3', 'País 2', 3690)
# ('2022-10-10', 'Producto 3', 'País 2', 7282)
# ('2022-08-14', 'Producto 3', 'País 2', 5943)
# ('2022-03-18', 'Producto 3', 'País 3', 2880)
# ('2022-05-12', 'Producto 2', 'País 1', 7749)
# ('2022-06-05', 'Producto 1', 'País 2', 642)
# ('2022-09-15', 'Producto 1', 'País 1', 628)
# ('2022-02-24', 'Producto 3', 'País 3', 6333)
# ('2022-06-13', 'Producto 1', 'País 2', 8577)
# ('2022-07-08', 'Producto 3', 'País 3', 1616)
# ('2022-07-14', 'Producto 1', 'País 1', 1718)
# ('2022-02-09', 'Producto 3', 'País 3', 4027)
# ('2022-07-15', 'Producto 3', 'País 1', 4005)
# ('2022-03-05', 'Producto 2', 'País 2', 4587)
# ('2022-04-22', 'Producto 1', 'País 1', 8494)
# ('2022-07-04', 'Producto 2', 'País 3', 5285)
# ('2022-03-08', 'Producto 3', 'País 1', 4635)
# ('2022-12-09', 'Producto 2', 'País 3', 3494)
# ('2022-10-14', 'Producto 3', 'País 3', 7299)
# ('2022-03-20', 'Producto 1', 'País 2', 8693)
# ('2022-03-28', 'Producto 2', 'País 2', 4561)
# ('2022-07-19', 'Producto 2', 'País 2', 9680)
# ('2022-05-27', 'Producto 1', 'País 3', 6175)
# ('2022-04-20', 'Producto 2', 'País 2', 9874)
# ('2022-07-27', 'Producto 2', 'País 1', 7800)
# ('2022-02-01', 'Producto 3', 'País 1', 8454)
# ('2022-07-12', 'Producto 2', 'País 2', 7305)
# ('2022-07-08', 'Producto 2', 'País 2', 8077)
# ('2022-07-28', 'Producto 1', 'País 1', 6715)
# ('2022-05-24', 'Producto 2', 'País 2', 2148)
# ('2022-05-18', 'Producto 1', 'País 1', 8782)
# ('2022-12-23', 'Producto 2', 'País 2', 8314)
# ('2022-07-11', 'Producto 1', 'País 1', 7464)
