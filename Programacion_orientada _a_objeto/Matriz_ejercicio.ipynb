# %% [markdown]
# Programa matrices
# Inicio programa
#
#     publico procedimiento matriz_zeros(entero f, entero c):
#     inicio procedimiento
#         matriz<-- inicializa lista vacia
#         Para i en rango de f hacer:
#                 m<-- inicializar lista vacia
#                 Para j in en rango de c hacer:
#                     m<-- añadir valor 0
#                 matriz<-- agregar valor de m
#         devolver matriz
#
#     Clase Matriz
#     atributos
#         publico f
#         publico c
#         privado elemento
#
#     inicio clase
#     publico procedimiento inicializar(Matriz: propio, lista: f, lista c):
#     inicio procedimiento
#         propio.elemento <-- llamar a la funcion matriz_zeros y pasar valores de f y c
#     fin procedimiento
#
#     publico funcion representar (Matrices: propio):
#         inicio funcion
#             cadena<-- inicializar cadena vacia
#             Para c en propio.elemento hacer:
#                 cadena<-- pasar valor de c a cadena y guardarlo
#             devolver cadena
#         fin funcion
#
#     publico obtener_filas(Matrices: propio):
#         inicio funcion
#             devolver la longitud de la variable elemento
#         fin funcion
#
#     publico obtener_columnas(Matrices: propio):
#         inicio funcion
#             devolver indice 0 de la longitud de la variable elemento
#         fin funcion
#
#     publico cambiar_elemento(Matrices: propio, entero f, entero c, entero valor):
#         inicio procedimiento
#             elemento<-- de los parametros de f y c agregar los valores de valor (enteros)
#         fin procedimiento
#
#     publico obtener_elemento(Matrices: propio, entero i, entero j):
#         inicio funcion
#             elemento<-- obtiene los elementos de i y j del bucle de la funcion matriz_zeros y devuelve el valor de elemento
#             devolver elemento
#         fin funcion
#
#     publico redimensionar(Matrices: propio, entero f, entero c):
#         inicio procedimiento
#             elemento<-- llama a la funcion matriz_zeros y pasar valores de f y c
#         fin procedimiento
#
#     publico sumar (Matrices: propio, entero m):
#         inicio procedimiento
#             Para i en rango de la funcion obtener_filas hacer:
#                 Para j en rango de la funcion obtener_columnas hacer:
#                     cambiar_elemento<-- llamar a las funciones obtener_elemento con los parametros de i y j y sumarlos con la funcion obtener_elemento de i,j
#
#         fin funcion
#     fin clase
# fin programa

# %%
def matriz_zeros(f, c):
    matriz=[]
    for i in range(f):
        m=[]
        for j in range(c):
            m.append(0)
        matriz.append(m)
    return matriz

matriz_zeros(2,2)

class Matriz:
    
    def __init__(self, f, c):
        self.__elemento= matriz_zeros(f,c)

    def __str__(self):
        cadena=''
        for c in self.__elemento:
            cadena+= str(c) + '\n'
        return cadena

    def obtener_filas(self):
        return len(self.__elemento)
    
    def obtener_columnas(self):
        return len(self.__elemento[0])
    
    def cambiar_elemento(self, f,c, valor):
        self.__elemento[f][c]= valor 
        #return valor

    def obtener_elemento(self,i,j):
        return self.__elemento[i][j]

    def redimensionar(self, f,c):
        self.__elemento= matriz_zeros(f,c)

    def sumar(self,m):
        for i in range(self.obtener_filas):
            for j in range(self.obtener_columnas):
                self.cambiar_elemento(i,j, self.obtener_elemento(i,j)+m.obtener_elemento(i,j) )


a= Matriz(2,2)

#a.obtener_filas()
#print(a)
#a.obtener_columnas()
#a.cambiar_elemento(0,0,5)
#a.obtener_elemento(0,0)
#print(a)
#a.redimensionar(5,5)
#print(a)
#a.sumar(10)
